# %%
import cv2
import math
import csv
import os
import matplotlib.pyplot as plt
from ultralytics import YOLO
from PIL import Image, ImageDraw, ImageFont
from ultralytics.solutions.solutions import BaseSolution
from ultralytics.utils.plotting import Annotator, colors
import time 
# %matplotlib inline
# Out:
# /home/iabd/anaconda3/envs/iabd_3_9/lib/python3.9/site-packages/torch/utils/_pytree.py:185: FutureWarning: optree is installed but the version is too old to support PyTorch Dynamo in C++ pytree. C++ pytree support is disabled. Please consider upgrading optree using `python3 -m pip install --upgrade 'optree>=0.13.0'`.
#   warnings.warn(

# %% [markdown]
# https://www.digitalocean.com/community/tutorials/what-is-new-with-yolo

# %% [markdown]
# ## EJERCICIO 1
# Vamos a usar el modleo YOLOv11 para detectar objetos en una imagen (en este caso vamos a aplicar el modelo directamente sin entrenarlo).
# Vamos a aplicarlo en las imagenes deteccion_objetos.jpg y bus.jpg
#
# Partiendo de la imagen deteccion_objetos.jpg y bus.jpg.

# %%
ruta_imgs = 'recursos/5_5/'
imgs_arr = [ruta_imgs+"deteccion_objetos.jpg",ruta_imgs+"bus.jpg"]
# cargar modelo yolo11
model = YOLO("recursos/5_5/yolo/yolo11n.pt")   

results = model(imgs_arr)
for res in results:
    res.show()
# Out:
# 0: 640x640 11 persons, 7 bicycles, 4 cars, 2 fire hydrants, 19.8ms
# 1: 640x640 4 persons, 1 bus, 19.8ms
# Speed: 5.2ms preprocess, 19.8ms inference, 61.9ms postprocess per image at shape (1, 3, 640, 640)
# ** Message: 19:50:59.887: main.vala:507: Starting session with system profile

# %% [markdown]
# ## EJERCICIO 2
# Vamos a repetir el ejercicio pero ahora vamos a modificar la salida para que quede de la siguiente forma:
#
# ![Imagen con la el resultado que se quiere obtener 1](recursos/5_5/deteccion_objetos_solucion.png)
#
# ![Imagen con la el resultado que se quiere obtener 1](recursos/5_5/bus_solucion.png)
#
# Además sólo quiero que detecte los objetos cuya probabilidad sea mayor al 50%.
#
# Ten en cuenta que al aplicar el modelo a una imagen devuelve diferentes datos:
#  * Cajas:
#     * Clase (cls)
#     * Probabilidad (score)
#     * Coordenadas de la caja xyxy
#
# Para representar la imagen y añadir rectángulos, texto... puedes usar Image, ImageDraw, ImageFont de PIL. Dibujas la imagen con .Draw de (ImageDraw) con .rectangle y .text puedes ir añadiendo texto y rectángulos.

# %%
clases = results[0].names
colores = ['cyan','orange','pink','green','yellow','red','blue','white']
guia = {}

# %%
for i,res in enumerate(results):    
    boxes = res.boxes  # Boxes object for bounding box outputs
    txt = ''
    filtrados = []
    for j,(cls,prob,coords) in enumerate(zip(boxes.cls,boxes.conf,boxes.xyxy)):
        if prob > 0.5:      # probabilidad mayor del 50%            
            # datos prediccion
            filtrados.append([cls,prob,coords])
            txt += 'Recuadro {}--> Clase: {},\t Score: {},\t Caja: {}\n'.format(j, clases[int(cls)], prob, coords)
            if int(cls) not in guia.keys(): 
                print(len(guia.keys()))
                guia[int(cls)] = colores[len(guia.keys())]
    # imagen
    img = Image.open(imgs_arr[i])
    draw = ImageDraw.Draw(img)
    font = ImageFont.truetype("usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf", size=30)

    for i,caso in enumerate(filtrados):
        coords = caso[2]
        color = guia[int(caso[0])]
        draw.rectangle([coords[0], coords[1], coords[2], coords[3]], outline=color, width=5)
        draw.rectangle([coords[0], coords[1]-30, coords[0]+2 + 40, coords[1]],fill="black")
        draw.rectangle([coords[0]+2, coords[1]-28, coords[0] + 40, coords[1]-2],fill=color)
        draw.text((coords[0]+8, coords[1]-32), str(i), fill="black",font=font)

    # mostrar resultados
    plt.figure(figsize=(13,7))
    plt.imshow(img)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
    print(txt)
# Out:
# ** Message: 19:51:00.030: main.vala:507: Starting session with system profile
# 0
# 1
# 2
# Recuadro 0--> Clase: car,	 Score: 0.8778764605522156,	 Caja: tensor([479.8883, 683.6398, 580.6799, 744.2516], device='cuda:0')
# Recuadro 1--> Clase: person,	 Score: 0.8711369633674622,	 Caja: tensor([723.8831, 699.6281, 794.2302, 927.2527], device='cuda:0')
# Recuadro 2--> Clase: car,	 Score: 0.8497547507286072,	 Caja: tensor([624.3212, 692.6537, 756.9240, 802.4709], device='cuda:0')
# Recuadro 3--> Clase: person,	 Score: 0.8445959687232971,	 Caja: tensor([220.4718, 685.4314, 259.8442, 814.4322], device='cuda:0')
# Recuadro 4--> Clase: person,	 Score: 0.8234404921531677,	 Caja: tensor([828.3610, 701.1053, 935.8299, 954.4529], device='cuda:0')
# Recuadro 5--> Clase: bicycle,	 Score: 0.7793213725090027,	 Caja: tensor([817.9751, 812.5693, 959.1559, 958.2740], device='cuda:0')
# Recuadro 6--> Clase: bicycle,	 Score: 0.7656781673431396,	 Caja: tensor([116.6321, 782.1196, 367.2387, 944.4985], device='cuda:0')
# Recuadro 7--> Clase: person,	 Score: 0.7158570885658264,	 Caja: tensor([183.0309, 686.3452, 216.2440, 786.7228], device='cuda:0')
# Recuadro 8--> Clase: bicycle,	 Score: 0.6700230240821838,	 Caja: tensor([ 995.5506,  823.9893, 1023.6957,  891.5317], device='cuda:0')
# Recuadro 9--> Clase: person,	 Score: 0.663038432598114,	 Caja: tensor([118.0966, 681.2939, 164.6554, 789.5504], device='cuda:0')
# Recuadro 10--> Clase: bicycle,	 Score: 0.5932632088661194,	 Caja: tensor([ 999.6135,  724.9155, 1023.5314,  795.2957], device='cuda:0')
# Recuadro 11--> Clase: person,	 Score: 0.582478940486908,	 Caja: tensor([958.7380, 661.0289, 987.2277, 746.7089], device='cuda:0')
# Recuadro 12--> Clase: car,	 Score: 0.5690413117408752,	 Caja: tensor([312.8179, 673.8903, 387.1542, 726.8175], device='cuda:0')
# Recuadro 13--> Clase: person,	 Score: 0.5579710602760315,	 Caja: tensor([101.9461, 667.9188, 129.9327, 757.8470], device='cuda:0')
#
# 3
# Recuadro 0--> Clase: bus,	 Score: 0.9391075372695923,	 Caja: tensor([ 11.9472, 228.3151, 799.1895, 735.3087], device='cuda:0')
# Recuadro 1--> Clase: person,	 Score: 0.9017204642295837,	 Caja: tensor([ 48.6464, 398.2117, 243.0680, 904.5064], device='cuda:0')
# Recuadro 2--> Clase: person,	 Score: 0.8498591780662537,	 Caja: tensor([670.6041, 392.3168, 810.0000, 879.6082], device='cuda:0')
# Recuadro 3--> Clase: person,	 Score: 0.8376365900039673,	 Caja: tensor([223.0595, 405.5998, 345.2839, 859.7147], device='cuda:0')

# %%
# chuleta atributos
""" for res in results:    
    boxes = res.boxes          # Boxes object for bounding box outputs
    masks = res.masks          # Masks object for segmentation masks outputs
    keypoints = res.keypoints          # Keypoints object for pose outputs
    probs = res.probs          # Probs object for classification outputs
    obb = res.obb            # Oriented boxes object for OBB outputs
    res.show()              # display to screen
    res.save(filename="result.jpg")          # save to disk
    print(boxes.cls)
    print(boxes.conf) """
# Out:
# ' for res in results:    \n    boxes = res.boxes          # Boxes object for bounding box outputs\n    masks = res.masks          # Masks object for segmentation masks outputs\n    keypoints = res.keypoints          # Keypoints object for pose outputs\n    probs = res.probs          # Probs object for classification outputs\n    obb = res.obb            # Oriented boxes object for OBB outputs\n    res.show()              # display to screen\n    res.save(filename="result.jpg")          # save to disk\n    print(boxes.cls)\n    print(boxes.conf) '

# %% [markdown]
# ## EJERCICIO 3
# YOLOv11 también sirve para segmentación, aplica segmentación a las dos imágenes con las que estamos trabajando

# %%
#segmentation  
model = YOLO('recursos/5_5/yolo/yolo11n-seg.pt')  
results = model(imgs_arr)  
for res in results:
    res.show()
# Out:
# 0: 640x640 11 persons, 8 bicycles, 3 cars, 1 backpack, 8.6ms
# 1: 640x640 4 persons, 1 bus, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)
# ** Message: 19:51:01.063: main.vala:507: Starting session with system profile

# %% [markdown]
# ## EJERCICIO 4
# De manera similar, podemos hacer la estimación de pose. Hazlo con las imágenes con las que estamos trabajando.

# %%
model = YOLO('recursos/5_5/yolo/yolo11n-pose.pt')  
results = model(imgs_arr)  
for res in results:
    res.show()
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n-pose.pt to 'recursos/5_5/yolo/yolo11n-pose.pt'...
# ** Message: 19:51:01.285: main.vala:507: Starting session with system profile
# 100%|██████████| 5.97M/5.97M [00:00<00:00, 21.5MB/s]
# 0: 640x640 2 persons, 7.7ms
# 1: 640x640 4 persons, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# ** Message: 19:51:03.125: main.vala:507: Starting session with system profile

# %% [markdown]
# ## EJERCICIO 5
# Haz lo que se hace en el siguiente video:
#
# https://www.youtube.com/watch?v=_YbEna8UNcU
#
# Tienes parte del código en:
#
# https://www.albertcoronado.com/2024/11/12/tutorial-yolo-11/
#
# Para la parte fine tuning tienes que entrenar el modelo para que distina matrículas de coche, para entrenar el modelo utiliza el dataset que puedes descargar de:
#
# https://universe.roboflow.com/parag-parmar-3qpin/car_license_plate-ypwmk/dataset/1
#
# NOTA: HE CONSEGUIDO QUE FUNCIONE BIEN CV2 PERO ABRIENDO PRIMERO UNA IMAGEN:
# ```
# img = cv2.imread('Datos/image3.jpg')
# cv2.imshow("SAPA", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# ```

# %%
img = cv2.imread('recursos/imgs/5_3_2/lemon.jpeg')
cv2.imshow("SAPA", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# camara 
model = YOLO("recursos/5_5/yolo/yolo11x.pt")
cap = cv2.VideoCapture(0)

font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 0.7
color = (0, 250, 0)
thickness = 3
start = time.time()

while True:
    success, img = cap.read()
    results = model( img, stream=True )

    for r in results:
        for box in r.boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)

            confidence = math.ceil((box.conf[0]*100))
            
            cv2.rectangle(img, ( x1, y1 ), ( x2, y2 ), color, 1)
            cv2.putText(img, r.names[ int( box.cls[0] ) ]+" "+str(confidence)+"%", [ x1+4, y1+25 ], font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)

    aux = time.time()-start
    if aux > 10:
        print('\nTiempo Fin ',aux)
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@170.406] global cap_gstreamer.cpp:1173 isPipelinePlaying OpenCV | GStreamer warning: GStreamer: pipeline have not been created
# 0: 480x640 6 persons, 5 chairs, 1 tv, 3 laptops, 45.3ms
# Speed: 4.8ms preprocess, 45.3ms inference, 90.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 3 laptops, 22.1ms
# Speed: 2.5ms preprocess, 22.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 3 laptops, 28.4ms
# Speed: 1.5ms preprocess, 28.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 22.6ms
# Speed: 2.3ms preprocess, 22.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 18.4ms
# Speed: 1.6ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 20.1ms
# Speed: 2.0ms preprocess, 20.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 19.8ms
# Speed: 1.4ms preprocess, 19.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 18.4ms
# Speed: 1.2ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 18.4ms
# Speed: 1.7ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 16.7ms
# Speed: 1.2ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 2 chairs, 1 tv, 1 laptop, 1 cell phone, 16.1ms
# Speed: 1.5ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 1 cell phone, 20.1ms
# Speed: 2.1ms preprocess, 20.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 20.1ms
# Speed: 1.6ms preprocess, 20.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 2 chairs, 2 tvs, 1 laptop, 17.0ms
# Speed: 1.2ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 3 chairs, 2 tvs, 1 laptop, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 2 chairs, 2 tvs, 1 laptop, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 2 chairs, 2 tvs, 1 laptop, 22.9ms
# Speed: 1.9ms preprocess, 22.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 2 chairs, 2 tvs, 1 laptop, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 1 laptop, 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 1 laptop, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 3 chairs, 2 tvs, 1 laptop, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 2 chairs, 2 tvs, 2 laptops, 17.8ms
# Speed: 1.6ms preprocess, 17.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 15.1ms
# Speed: 2.0ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 4 chairs, 2 tvs, 2 laptops, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 15.9ms
# Speed: 1.4ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 2 laptops, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 2 laptops, 18.9ms
# Speed: 2.2ms preprocess, 18.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 17.1ms
# Speed: 1.5ms preprocess, 17.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 15.5ms
# Speed: 2.1ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 16.7ms
# Speed: 1.8ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 1 cell phone, 22.3ms
# Speed: 1.5ms preprocess, 22.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 21.6ms
# Speed: 1.9ms preprocess, 21.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 17.4ms
# Speed: 1.6ms preprocess, 17.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 16.5ms
# Speed: 1.6ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 18.8ms
# Speed: 1.6ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 17.0ms
# Speed: 1.9ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 2 laptops, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 3 laptops, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 15.8ms
# Speed: 1.3ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 3 laptops, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 15.6ms
# Speed: 1.7ms preprocess, 15.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 3 laptops, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 3 laptops, 17.7ms
# Speed: 1.5ms preprocess, 17.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 3 laptops, 18.0ms
# Speed: 1.8ms preprocess, 18.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 15.3ms
# Speed: 1.5ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 3 laptops, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 17.5ms
# Speed: 1.8ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 3 laptops, 16.6ms
# Speed: 1.6ms preprocess, 16.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 3 laptops, 14.8ms
# Speed: 1.5ms preprocess, 14.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 17.0ms
# Speed: 2.3ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 17.2ms
# Speed: 1.4ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 3 laptops, 17.7ms
# Speed: 1.7ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 17.4ms
# Speed: 1.6ms preprocess, 17.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 24.2ms
# Speed: 1.8ms preprocess, 24.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 3 laptops, 15.8ms
# Speed: 1.9ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 17.5ms
# Speed: 1.4ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 17.0ms
# Speed: 1.7ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 16.9ms
# Speed: 1.5ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 18.8ms
# Speed: 2.1ms preprocess, 18.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 1 dining table, 2 tvs, 1 laptop, 15.5ms
# Speed: 1.6ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 15.3ms
# Speed: 1.2ms preprocess, 15.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 15.8ms
# Speed: 1.2ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 16.1ms
# Speed: 1.6ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 13.9ms
# Speed: 1.4ms preprocess, 13.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 1 tv, 2 laptops, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 17.3ms
# Speed: 1.2ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 14.1ms
# Speed: 1.6ms preprocess, 14.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 19.7ms
# Speed: 1.7ms preprocess, 19.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 1 dining table, 2 tvs, 1 laptop, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 dining table, 2 tvs, 1 laptop, 13.8ms
# Speed: 1.4ms preprocess, 13.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 16.9ms
# Speed: 1.3ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 16.5ms
# Speed: 1.3ms preprocess, 16.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 dining table, 2 tvs, 1 laptop, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 1 laptop, 16.1ms
# Speed: 1.8ms preprocess, 16.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 dining table, 2 tvs, 2 laptops, 1 cell phone, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 3 laptops, 1 cell phone, 16.8ms
# Speed: 1.1ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 dining table, 2 tvs, 2 laptops, 15.2ms
# Speed: 1.6ms preprocess, 15.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 16.6ms
# Speed: 1.6ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 5 chairs, 2 tvs, 1 laptop, 15.4ms
# Speed: 1.6ms preprocess, 15.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 1 laptop, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 dining table, 2 tvs, 2 laptops, 13.6ms
# Speed: 1.4ms preprocess, 13.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 4 chairs, 2 tvs, 2 laptops, 16.9ms
# Speed: 1.3ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 1 laptop, 15.0ms
# Speed: 1.5ms preprocess, 15.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 chair, 2 tvs, 1 laptop, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 14.5ms
# Speed: 1.5ms preprocess, 14.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 2 chairs, 2 tvs, 2 laptops, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 1 laptop, 17.8ms
# Speed: 2.2ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 2 tvs, 2 laptops, 17.7ms
# Speed: 1.3ms preprocess, 17.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 15.1ms
# Speed: 1.7ms preprocess, 15.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 2 laptops, 17.1ms
# Speed: 1.9ms preprocess, 17.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 tvs, 2 laptops, 13.7ms
# Speed: 1.3ms preprocess, 13.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 16.7ms
# Speed: 1.7ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 1 laptop, 15.1ms
# Speed: 1.5ms preprocess, 15.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 1 cell phone, 15.8ms
# Speed: 1.8ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.0ms
# Speed: 1.6ms preprocess, 15.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 17.9ms
# Speed: 1.9ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 2 laptops, 15.6ms
# Speed: 1.8ms preprocess, 15.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 2 chairs, 1 tv, 1 laptop, 17.0ms
# Speed: 1.7ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 20.7ms
# Speed: 1.9ms preprocess, 20.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 3 chairs, 1 tv, 2 laptops, 1 cell phone, 16.4ms
# Speed: 1.7ms preprocess, 16.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 2 chairs, 1 tv, 2 laptops, 1 cell phone, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 1 cell phone, 17.8ms
# Speed: 1.6ms preprocess, 17.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 19.8ms
# Speed: 1.6ms preprocess, 19.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 tv, 2 laptops, 1 cell phone, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 1 handbag, 3 chairs, 1 tv, 1 laptop, 15.8ms
# Speed: 1.3ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.2ms
# Speed: 1.6ms preprocess, 17.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 3 chairs, 1 tv, 1 laptop, 15.7ms
# Speed: 1.6ms preprocess, 15.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.4ms
# Speed: 1.3ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 persons, 4 chairs, 1 tv, 1 laptop, 16.1ms
# Speed: 1.4ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.8ms
# Speed: 1.1ms preprocess, 17.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 16.2ms
# Speed: 1.3ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 20.1ms
# Speed: 1.7ms preprocess, 20.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 3 laptops, 18.1ms
# Speed: 1.8ms preprocess, 18.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.5ms
# Speed: 1.5ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.4ms
# Speed: 1.7ms preprocess, 15.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.8ms
# Speed: 2.5ms preprocess, 17.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.1ms
# Speed: 1.7ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 persons, 3 chairs, 1 tv, 2 laptops, 16.3ms
# Speed: 1.7ms preprocess, 16.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 3 laptops, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.6ms
# Speed: 1.3ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 2 laptops, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 2 laptops, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.4ms
# Speed: 1.4ms preprocess, 17.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.0ms
# Speed: 1.3ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 19.8ms
# Speed: 2.2ms preprocess, 19.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.7ms
# Speed: 1.9ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 1 tv, 1 laptop, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.5ms
# Speed: 1.6ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.3ms
# Speed: 1.7ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 2 laptops, 17.3ms
# Speed: 1.8ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.1ms
# Speed: 1.5ms preprocess, 17.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 18.0ms
# Speed: 1.7ms preprocess, 18.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.4ms
# Speed: 1.7ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 2 tvs, 1 laptop, 16.9ms
# Speed: 1.8ms preprocess, 16.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 1 laptop, 17.0ms
# Speed: 1.8ms preprocess, 17.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.3ms
# Speed: 1.7ms preprocess, 17.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 28.6ms
# Speed: 1.6ms preprocess, 28.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.2ms
# Speed: 1.5ms preprocess, 15.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 21.8ms
# Speed: 1.9ms preprocess, 21.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 18.4ms
# Speed: 1.8ms preprocess, 18.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 1.6ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.2ms
# Speed: 1.7ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.6ms
# Speed: 2.1ms preprocess, 17.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 17.7ms
# Speed: 1.8ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.7ms preprocess, 16.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 18.1ms
# Speed: 1.9ms preprocess, 18.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.9ms
# Speed: 1.6ms preprocess, 17.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 3 laptops, 19.6ms
# Speed: 2.1ms preprocess, 19.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 3 laptops, 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 chair, 2 tvs, 3 laptops, 15.9ms
# Speed: 1.6ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.5ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 2 laptops, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 1 laptop, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 1 laptop, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.4ms
# Speed: 1.6ms preprocess, 17.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.5ms
# Speed: 1.6ms preprocess, 17.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 4 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.0ms
# Speed: 1.6ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 23.0ms
# Speed: 2.1ms preprocess, 23.0ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 4 chairs, 1 tv, 2 laptops, 17.5ms
# Speed: 2.4ms preprocess, 17.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 15.3ms
# Speed: 1.6ms preprocess, 15.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 4 chairs, 1 tv, 2 laptops, 21.5ms
# Speed: 1.7ms preprocess, 21.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.7ms
# Speed: 1.6ms preprocess, 16.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 5 chairs, 1 tv, 2 laptops, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.9ms
# Speed: 1.7ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 18.4ms
# Speed: 1.6ms preprocess, 18.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 17.9ms
# Speed: 1.7ms preprocess, 17.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.3ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 21.1ms
# Speed: 2.2ms preprocess, 21.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.4ms
# Speed: 1.4ms preprocess, 15.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.3ms
# Speed: 1.4ms preprocess, 17.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 3 laptops, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.3ms
# Speed: 1.6ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 2 laptops, 15.8ms
# Speed: 1.6ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 4 laptops, 16.3ms
# Speed: 1.4ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 3 laptops, 16.0ms
# Speed: 1.5ms preprocess, 16.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.9ms
# Speed: 1.5ms preprocess, 16.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.9ms
# Speed: 1.4ms preprocess, 17.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.1ms
# Speed: 1.4ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.2ms
# Speed: 1.7ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.8ms
# Speed: 1.6ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.4ms
# Speed: 1.5ms preprocess, 16.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 18.2ms
# Speed: 1.6ms preprocess, 18.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 18.9ms
# Speed: 1.9ms preprocess, 18.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 18.5ms
# Speed: 1.6ms preprocess, 18.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.0ms
# Speed: 1.8ms preprocess, 16.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 6 chairs, 1 tv, 1 laptop, 17.4ms
# Speed: 1.6ms preprocess, 17.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.4ms
# Speed: 2.0ms preprocess, 16.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.1ms
# Speed: 1.7ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.2ms
# Speed: 1.3ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 18.3ms
# Speed: 1.7ms preprocess, 18.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.7ms
# Speed: 1.2ms preprocess, 16.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 7 chairs, 1 tv, 1 laptop, 18.4ms
# Speed: 2.6ms preprocess, 18.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.5ms preprocess, 16.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 19.7ms
# Speed: 1.7ms preprocess, 19.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.6ms
# Speed: 1.8ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.9ms
# Speed: 1.6ms preprocess, 17.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.6ms
# Speed: 2.0ms preprocess, 17.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 2.1ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 6 chairs, 1 tv, 1 laptop, 17.6ms
# Speed: 1.4ms preprocess, 17.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 15.9ms
# Speed: 1.5ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.5ms
# Speed: 1.4ms preprocess, 16.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 18.5ms
# Speed: 1.3ms preprocess, 18.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.8ms
# Speed: 1.7ms preprocess, 17.8ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 1 laptop, 16.9ms
# Speed: 1.3ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.1ms
# Speed: 1.6ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.5ms
# Speed: 1.5ms preprocess, 16.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 16.9ms
# Speed: 1.4ms preprocess, 16.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 17.0ms
# Speed: 1.4ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.8ms
# Speed: 1.7ms preprocess, 15.8ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.7ms
# Speed: 1.7ms preprocess, 17.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 22.2ms
# Speed: 1.5ms preprocess, 22.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 2 tvs, 1 laptop, 16.7ms
# Speed: 1.7ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 15.5ms
# Speed: 1.4ms preprocess, 15.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 17.5ms
# Speed: 1.5ms preprocess, 17.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 16.6ms
# Speed: 1.4ms preprocess, 16.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 1 handbag, 5 chairs, 1 dining table, 2 tvs, 2 laptops, 17.6ms
# Speed: 1.7ms preprocess, 17.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 2 tvs, 3 laptops, 16.7ms
# Speed: 1.5ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 16.8ms
# Speed: 1.7ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 3 laptops, 21.9ms
# Speed: 1.9ms preprocess, 21.9ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 17.0ms
# Speed: 1.6ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 20.1ms
# Speed: 1.7ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 2 chairs, 1 tv, 2 laptops, 16.6ms
# Speed: 1.6ms preprocess, 16.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 20.2ms
# Speed: 1.4ms preprocess, 20.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 6 chairs, 1 tv, 2 laptops, 18.1ms
# Speed: 1.5ms preprocess, 18.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 2 tvs, 2 laptops, 16.2ms
# Speed: 1.6ms preprocess, 16.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 2 tvs, 2 laptops, 16.1ms
# Speed: 1.3ms preprocess, 16.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 2 tvs, 1 laptop, 15.9ms
# Speed: 1.3ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.2ms
# Speed: 1.5ms preprocess, 17.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 1 laptop, 17.3ms
# Speed: 1.6ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.7ms
# Speed: 1.6ms preprocess, 15.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 17.7ms
# Speed: 1.5ms preprocess, 17.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 5 chairs, 1 tv, 2 laptops, 16.4ms
# Speed: 1.6ms preprocess, 16.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.5ms
# Speed: 2.1ms preprocess, 17.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 16.2ms
# Speed: 1.5ms preprocess, 16.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 19.9ms
# Speed: 1.5ms preprocess, 19.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 1 laptop, 15.5ms
# Speed: 1.3ms preprocess, 15.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.3ms
# Speed: 1.5ms preprocess, 17.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 tv, 2 laptops, 16.1ms
# Speed: 1.6ms preprocess, 16.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 15.7ms
# Speed: 1.4ms preprocess, 15.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 16.7ms
# Speed: 1.4ms preprocess, 16.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 1 laptop, 17.0ms
# Speed: 1.5ms preprocess, 17.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 dining table, 1 tv, 2 laptops, 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 3 chairs, 1 dining table, 1 tv, 1 laptop, 16.8ms
# Speed: 1.4ms preprocess, 16.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 16.3ms
# Speed: 1.5ms preprocess, 16.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 tv, 2 laptops, 15.8ms
# Speed: 1.4ms preprocess, 15.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 dining table, 1 tv, 2 laptops, 17.1ms
# Speed: 1.6ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 persons, 4 chairs, 1 dining table, 1 tv, 1 laptop, 17.1ms
# Speed: 1.4ms preprocess, 17.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# fine tuning
path: './recursos/datasets/car_license_plate.v1i.yolov11/'

# Carpeta con las imágenes de entrenamiento
train: './train/images'

# Carpeta con las imágenes de validación(Usadas para entrenar y sacar métricas)
val: './valid/images'

# Carpeta con las imágenes de tetst(No usadas para entrenar y solo para sacar métricas)
test: './test/images'

# Número total de classes(Tipos de objeto)
nc: 43

# %% [markdown]
# ## EJERCICIO 6
# Repite el fine tuning del apartado anterior pero ahora en vez de como un comando en la terminal con código de python

# %% [markdown]
# ## EJERCICIO 7
# Vamos a contar los pasajeros de un autobus.
#
# Sigue las instrucciones del siguiente video:
#
# https://www.youtube.com/watch?v=hTI0Aj__SLE
#
# ELIMINA LOS COMENTARIOS QUE HAY EN EL CÓDIGO Y COMENTA EL CÓDIGO CON TUS PROPIAS PALABRAS

# %% [markdown]
# ## EJERCICIO 8
# Adapta el código anterior para que cuente vehículos en el video vehicle-counting.mp4 (tiene que contar por separado coches y camiones)

# %% [markdown]
# ## EJERCICIO 9
# Adapta el ejercicio anterior para que en vez de coches cuente matrículas usando el modelo que has creado en el ejercicio 6.
#
# Si el video del apartado anterior no te sirve porque no se ven bien las matrículas crea un video con la IA generativa (si el video creado es demasiado corto junta varios videos en uno)

# %% [markdown]
# ## EJERCICIO 10
# Vamos a hacer fine tuning sobre el modelo para segmentación SAM-2.
#
# Puedes sacar información de la siguiente página:
#
# https://blog.roboflow.com/fine-tune-sam-2-1/
#
# A la hora de conseguir el dataset, descargalo para no tener problemas con la API-KEY de Roboflow

# %% [markdown]
# ## EJERCICIO 11 (OPCIONAL)
# Haz fine tuning con sam2 o yolo11 para segmentación con otro dataset

# %% [markdown]
# ## EJERCICIO 12 (OPCIONAL)
# En el siguiente enlace encontraras diferentes modelos y trabajos sobre la visión por computación, prueba alguno de ellos (algunos que no funcionan porque las librerías se han actualizado y tienes que adaptarlos, otros son recientes y no deberías tener problemas).
#
# https://github.com/roboflow/notebooks
#
# ELIMINA LOS COMENTARIOS QUE HAY EN EL CÓDIGO Y COMENTA EL CÓDIGO CON TUS PROPIAS PALABRAS
