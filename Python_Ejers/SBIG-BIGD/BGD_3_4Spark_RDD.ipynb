# %% [markdown]
# # SPARK - RDD
# RDD, o Resilient Distributed Dataset, es una abstracción fundamental de Spark que representa una colección inmutable y distribuida de objetos que pueden ser procesados en paralelo.
#
# Características:
# * Resistencia
# * Inmutabilidad
# * Distribución
# * Paralelización
# * Tolerancia a fallos
#
# Antes de la versión 2.0, el principal interfaz para programar en Spark eran los RDD. Desde la versión 2.0, también existen los Dataset, que son RDD fuertemente tipados que además están optimizados a bajo nivel.
#
# Sobre los RDD se pueden hacer dos tipos de operaciones:
# * **Transformaciones**: operaciones que crean un nuevo RDD a partir del existente (p. ej., map, filter, flatMap, reduceByKey, groupBy).
# * **Acciones**: operaciones que devuelven un valor después de ejecutar un cálculo sobre el RDD (p. ej., collect, count, reduce, take).

# %% [markdown]
# ## CREAR SparkSession Y SparkContext

# %%
import pandas as pd
from pyspark.sql import SparkSession

spark = SparkSession.builder.master("local[*]").appName("pyspark_rdd").getOrCreate()
#spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
# Out:
# 24/01/21 18:21:16 WARN Utils: Your hostname, AINARA-MAC.local resolves to a loopback address: 127.0.0.1; using 192.168.0.109 instead (on interface en0)
# 24/01/21 18:21:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/01/21 18:21:17 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ## CREACIÓN DE UN RDD

# %% [markdown]
# ### CREAR UN RDD A PARTIR DE UN FICHERO DE TEXTO
# Podemos crear un RDD directamente desde un archivo de texto utilizando el método textFile del SparkContext. Cada línea del archivo se convierte en un elemento del RDD.

# %%
rdd = sc.textFile("Datos/el_quijote.txt")
#rdd.collect()

# %% [markdown]
# ### CREAR UN RDD A PARTIR DE UN CSV
# Para crear un RDD a partir de un archivo CSV, primero debemos leer el archivo CSV como un DataFrame y luego convertirlo en un RDD. Spark proporciona funciones específicas para leer archivos CSV.

# %%
df = spark.read.csv("Datos/pdi_sales.csv", header=True, inferSchema=True)
rdd = df.rdd
rdd.collect()
# Out:
# [Row(ProductID;Date;Zip;Units;Revenue;Country='725;1/15/1999;41540          ;1;115.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='787;6/6/2002;41540          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='788;6/6/2002;41540          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='940;1/15/1999;22587          ;1;687.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;1/15/1999;22587          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='734;4/10/2003;22587          ;1;330.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='769;2/15/1999;22587          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;1/15/1999;12555          ;1;846.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2254;1/15/1999;40217          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='31;5/31/2002;40217          ;1;761.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;13583          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='510;1/15/1999;22337          ;1;837.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;6/5/2002;22337          ;1;883;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='289;2/15/1999;13587          ;1;866;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='702;2/15/1999;13587          ;1;286.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;3/15/1999;13587          ;1;414.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='901;2/15/1999;13587          ;2;818.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;1/15/1999;22177          ;1;404;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;1/15/1999;22177          ;1;585.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='767;6/7/2002;22177          ;1;105;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1000;4/11/2003;13589          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;1/15/1999;21129          ;1;585.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='716;4/10/2003;21129          ;1;152.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='966;4/10/2003;21129          ;1;472.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;1/15/1999;42549          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;1/15/1999;42549          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2054;6/5/2002;42549          ;1;546;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2205;6/5/2002;42549          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2204;6/5/2002;42549          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;6/5/2002;42549          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2253;6/5/2002;42549          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='574;6/8/2002;13595          ;1;869.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;1/15/1999;21107          ;2;1603.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='727;1/15/1999;22149          ;1;63;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='472;4/10/2003;22149          ;1;961.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='921;1/15/1999;27499          ;1;525;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='946;5/31/2002;27499          ;1;693;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;2/15/1999;10119          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1066;1/15/1999;41066          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1065;1/15/1999;41066          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;6/6/2002;41066          ;1;624.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1188;1/15/1999;22359          ;1;472.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='36;2/15/1999;22359          ;1;414.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1014;2/15/1999;22359          ;1;86.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;1/15/1999;10243          ;1;535.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='532;3/15/1999;10243          ;1;556.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;4/10/2003;10243          ;2;989.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='647;4/10/2003;10243          ;1;922.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1014;5/31/2002;10243          ;1;86.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='571;6/11/2003;10243          ;1;527.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1990;1/15/1999;45138          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2396;6/10/2002;10245          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='906;4/12/2003;10247          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2240;4/13/2003;10247          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2241;4/13/2003;10247          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;4/13/2003;10247          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='433;2/15/1999;10247          ;1;804.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;1/15/1999;45130          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;1/15/1999;22761          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='769;5/31/2002;22761          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;2/15/1999;22761          ;1;280.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;2/15/1999;10315          ;1;346.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2254;2/15/1999;10315          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;10315          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2255;2/15/1999;10315          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;1/15/1999;10315          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='565;6/3/2002;10315          ;1;881.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;1/15/1999;22767          ;1;280.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='580;2/15/1999;10318          ;1;734.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;10318          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;10318          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;6/3/2002;10318          ;1;429.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;1/15/1999;41469          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;3/15/1999;10319          ;2;1630.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;5/31/2002;10319          ;1;120.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1215;2/15/1999;10319          ;1;362.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;2/15/1999;10319          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;1/15/1999;22111          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='445;6/6/2002;22111          ;1;860.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;22111          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1975;2/15/1999;10365          ;1;52.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1081;2/15/1999;10365          ;1;225.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;3/15/1999;10365          ;1;346.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2056;3/15/1999;10365          ;1;320.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='533;6/7/2002;10365          ;1;524.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='683;1/15/1999;10365          ;1;788;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;10365          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;2/15/1999;10367          ;1;851.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;3/15/1999;10367          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1017;6/8/2002;10367          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2407;2/15/1999;10367          ;1;73.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;10367          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='574;5/31/2002;40591          ;1;869.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;5/31/2002;40591          ;1;120.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1116;2/15/1999;40591          ;1;251.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;40591          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;4/12/2003;10407          ;1;1037.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2375;4/13/2003;10407          ;1;698.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1911;3/15/1999;10407          ;1;244.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2094;3/15/1999;10407          ;1;433.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='906;5/31/2002;10407          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='691;6/3/2002;10407          ;1;351.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;10407          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2287;2/15/1999;10407          ;1;840;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='513;2/15/1999;10407          ;1;451.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='580;2/15/1999;10407          ;1;734.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='739;5/31/2002;41470          ;1;173.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;5/31/2002;10409          ;1;945;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;6/8/2002;10409          ;1;829.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='580;2/15/1999;10409          ;1;734.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;6/3/2002;10409          ;1;1007.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='767;5/31/2002;41169          ;1;105;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='981;6/6/2002;41169          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;10435          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;3/15/1999;10435          ;2;829.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;4/11/2003;10435          ;1;643.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;1/15/1999;10435          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;5/31/2002;10435          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='967;5/31/2002;10435          ;1;672;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1157;3/15/1999;10435          ;1;377.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='645;3/15/1999;10435          ;2;1493.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;6/7/2002;10435          ;1;1007.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;1/15/1999;10435          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='862;4/10/2003;10435          ;2;608.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='488;4/11/2003;10435          ;1;1098.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='785;5/31/2002;10435          ;1;68.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;2/15/1999;10435          ;2;1692.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;10435          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;5/31/2002;40233          ;1;945;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;1/15/1999;10551          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1903;6/5/2002;10551          ;1;766.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1006;5/31/2002;41065          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;6/5/2002;41065          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;6/5/2002;41065          ;1;323.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;41065          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;2/15/1999;10553          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2046;5/31/2002;22041          ;1;433.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2071;5/31/2002;22417          ;1;346.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2074;5/31/2002;22417          ;1;335.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='599;2/15/1999;22417          ;1;753.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;5/31/2002;10557          ;1;540.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1000;6/8/2002;10557          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='426;6/10/2002;10557          ;1;843.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='94;6/10/2002;10557          ;1;892;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1204;3/15/1999;10559          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2353;5/31/2002;40597          ;1;414.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;6/7/2002;40597          ;1;480.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;40597          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2074;5/31/2002;40597          ;1;335.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='663;2/15/1999;40597          ;1;765.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='533;6/1/2002;10585          ;1;524.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='596;6/3/2002;10585          ;1;776.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;3/15/1999;10585          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='658;1/15/1999;10585          ;1;902.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1203;3/15/1999;10585          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='922;3/15/1999;10585          ;1;472.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='433;6/3/2002;10585          ;1;851.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='671;6/5/2002;10585          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='671;6/11/2003;10585          ;1;944.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2373;5/31/2002;41464          ;1;588;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;3/15/1999;10587          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='596;1/15/1999;10587          ;1;746.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;10587          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='599;2/15/1999;10587          ;1;753.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='488;6/4/2002;10587          ;1;1007.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='133;6/5/2002;10587          ;1;640;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;10587          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;2/15/1999;10587          ;1;846.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;5/31/2002;40212          ;1;299;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='530;2/15/1999;40212          ;1;619.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;5/31/2002;22305          ;1;120.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1383;6/5/2002;22305          ;1;341.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1384;6/5/2002;22305          ;1;341.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='638;4/9/2003;41063          ;1;1008.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='786;4/9/2003;40764          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1191;4/11/2003;10627          ;1;267.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1063;3/15/1999;10627          ;1;233.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2373;2/15/1999;10627          ;1;551.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;10627          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2388;3/15/1999;10629          ;1;309.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2234;3/15/1999;10629          ;1;65.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;4/10/2003;42369          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;6/5/2002;42369          ;1;323.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;42369          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2199;4/10/2003;22297          ;1;188.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='443;4/10/2003;22297          ;1;851.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='400;6/5/2002;22297          ;1;734.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;3/15/1999;10711          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='760;4/11/2003;10713          ;1;146.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='759;4/11/2003;10713          ;1;146.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='502;4/10/2003;22115          ;1;1105.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='599;2/15/1999;10715          ;1;753.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='669;4/10/2003;22087          ;1;1364.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='103;6/5/2002;22087          ;1;855.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;2/15/1999;22087          ;1;280.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='838;3/15/1999;10717          ;1;934.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1227;3/15/1999;10717          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='551;4/12/2003;10717          ;1;922.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;1/15/1999;10717          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;6/7/2002;10717          ;1;480.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2045;2/15/1999;10719          ;1;409.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='464;6/7/2002;10719          ;1;866.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='433;2/15/1999;10777          ;1;804.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='990;3/15/1999;10777          ;1;472.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;6/4/2002;10777          ;1;323.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;4/10/2003;22609          ;1;309.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1066;2/15/1999;22609          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='727;1/15/1999;45143          ;1;63;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2407;2/15/1999;45143          ;1;73.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;2/15/1999;45143          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='740;1/15/1999;41517          ;1;170.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;6/6/2002;41517          ;1;120.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;6/6/2002;41517          ;1;120.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;10785          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1066;1/15/1999;41749          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2235;6/6/2002;41749          ;1;70.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2234;6/6/2002;41749          ;1;70.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;4/12/2003;10787          ;1;913.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='683;2/15/1999;42389          ;1;788;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='530;3/15/1999;10789          ;1;619.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1157;3/15/1999;10789          ;1;377.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;2/15/1999;21149          ;1;301.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;3/15/1999;10823          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;3/15/1999;10823          ;1;293.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1836;4/10/2003;10823          ;1;146.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1014;5/31/2002;10823          ;1;86.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='663;2/15/1999;10823          ;1;765.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='330;2/15/1999;10823          ;1;577.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='467;6/5/2002;21073          ;1;900.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;10827          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='513;3/15/1999;10829          ;1;451.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;2/15/1999;10829          ;1;535.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1191;3/15/1999;10967          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2387;4/13/2003;10967          ;1;493.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2253;5/31/2002;10967          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;5/31/2002;10967          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2145;6/5/2002;22559          ;1;383.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;6/7/2002;22559          ;1;456.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2388;6/10/2002;12043          ;1;309.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;2/15/1999;12043          ;1;446;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='989;2/15/1999;12043          ;1;467.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='532;6/5/2002;45145          ;1;577.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='683;6/5/2002;45145          ;1;839.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='981;6/6/2002;45145          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='574;6/5/2002;22395          ;1;869.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='622;6/6/2002;22395          ;1;816.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1478;2/15/1999;22395          ;1;317.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;6/5/2002;22045          ;1;829.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='647;6/5/2002;45147          ;1;900.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;6/5/2002;45147          ;1;837.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2112;6/5/2002;22547          ;1;572.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2053;5/31/2002;22547          ;1;325.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;12101          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;2/15/1999;12101          ;1;301.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='642;4/11/2003;12101          ;1;903.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2112;6/5/2002;41179          ;1;572.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;2/15/1999;12103          ;1;585.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2270;5/31/2002;12103          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;3/15/1999;12103          ;1;446;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2359;6/5/2002;42657          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;12107          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;6/5/2002;42651          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;2/15/1999;12109          ;1;280.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='992;5/31/2002;12157          ;1;278.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='785;6/6/2002;22527          ;1;68.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='786;6/6/2002;22527          ;1;68.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='786;6/7/2002;22527          ;1;68.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;12159          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='500;4/12/2003;12159          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2083;3/15/1999;12159          ;1;309.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;3/15/1999;12159          ;1;585.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2074;2/15/1999;12159          ;1;328.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1836;6/6/2002;22089          ;1;146.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1182;1/15/1999;12163          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='727;1/15/1999;12165          ;1;63;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;4/10/2003;12165          ;1;110.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='761;4/10/2003;12165          ;1;173.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='512;6/6/2002;42107          ;1;230.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;42107          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2359;4/13/2003;12169          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2396;6/6/2002;42115          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='467;6/6/2002;41516          ;1;900.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='580;2/15/1999;41516          ;1;734.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;2/15/1999;41516          ;1;280.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='967;4/11/2003;12207          ;1;698.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;5/31/2002;12207          ;1;115.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='989;3/15/1999;12207          ;1;451.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;6/10/2002;12207          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2253;6/10/2002;12207          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;3/15/1999;12207          ;1;414.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2045;4/10/2003;12207          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;6/6/2002;22393          ;1;429.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;22393          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='433;4/14/2003;12209          ;1;880.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='966;6/6/2002;40468          ;1;488.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;3/15/1999;12247          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;2/15/1999;12249          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;3/15/1999;12249          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2016;5/31/2002;12249          ;1;304.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='671;6/7/2002;12249          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;4/11/2003;12249          ;1;433.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;2/15/1999;12277          ;1;346.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2050;5/31/2002;12277          ;1;503.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='597;2/15/1999;12277          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;12279          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;3/15/1999;12279          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1974;3/15/1999;12279          ;1;52.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;6/7/2002;12305          ;1;330.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1131;3/15/1999;12305          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='681;6/6/2002;41366          ;1;682.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;6/8/2002;12307          ;1;1007.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='838;3/15/1999;12309          ;1;934.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2016;3/15/1999;12351          ;1;299.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2332;5/31/2002;12351          ;1;367.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2094;3/15/1999;12351          ;1;433.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;3/15/1999;12351          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;6/3/2002;12351          ;1;317.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1000;6/7/2002;22085          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2056;2/15/1999;12353          ;1;325.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;6/7/2002;42279          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='94;6/7/2002;40229          ;1;892;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2284;3/15/1999;12357          ;1;293.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;3/15/1999;12357          ;1;115.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='472;4/14/2003;12357          ;1;961.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1894;1/15/1999;12359          ;1;682.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2371;3/15/1999;12359          ;1;551.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='976;6/7/2002;12359          ;1;314.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1061;6/3/2002;12359          ;1;149.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1062;6/3/2002;12359          ;1;149.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='195;2/15/1999;12359          ;1;750.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;2/15/1999;12359          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;12435          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1926;5/31/2002;12439          ;1;99.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1960;1/15/1999;12439          ;1;97.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1927;5/31/2002;12439          ;1;99.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1053;1/15/1999;12439          ;1;251.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1185;2/15/1999;22143          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2275;6/11/2003;12489          ;1;330.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;6/10/2002;12526          ;1;429.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2407;4/10/2003;12526          ;1;81.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2287;2/15/1999;12527          ;1;840;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;3/15/1999;12589          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;2/15/1999;12619          ;1;446;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;42283          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;2/15/1999;40880          ;2;692.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;2/15/1999;12627          ;1;105;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1116;3/15/1999;12627          ;1;251.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2045;3/15/1999;12627          ;1;409.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2074;3/15/1999;12627          ;1;328.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;1/15/1999;12627          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2277;5/31/2002;12627          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='816;6/7/2002;12627          ;1;330.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1201;6/7/2002;12627          ;1;577.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='757;2/15/1999;12627          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='551;4/11/2003;12627          ;1;922.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='635;6/3/2002;12627          ;2;1716.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='770;2/15/1999;12629          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1957;3/15/1999;12629          ;1;153.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1916;5/31/2002;12629          ;1;286.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='770;5/31/2002;12629          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;1/15/1999;12629          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;12629          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;6/4/2002;12629          ;1;837.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;2/15/1999;12629          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;2/15/1999;12629          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;12629          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='952;6/11/2003;12629          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;40723          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;40883          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;2/15/1999;12681          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;6/3/2002;12681          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;1/15/1999;12681          ;1;346.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;5/31/2002;12681          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='681;3/15/1999;12681          ;1;629.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='757;2/15/1999;12681          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2253;6/3/2002;12681          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='645;2/15/1999;12681          ;2;1493.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='769;2/15/1999;41239          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='770;2/15/1999;41239          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;2/15/1999;41352          ;1;301.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1230;5/31/2002;42799          ;1;525;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;5/31/2002;12687          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1915;5/31/2002;47804          ;1;467.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;2/15/1999;47804          ;1;446;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='400;2/15/1999;47804          ;1;683.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;47804          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;5/31/2002;47804          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;5/31/2002;47804          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1000;5/31/2002;47804          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;3/15/1999;47804          ;1;535.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;47804          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2410;3/15/1999;12689          ;1;99.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2252;5/31/2002;46485          ;1;136.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='989;3/15/1999;46485          ;1;467.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;3/15/1999;46485          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;1/15/1999;46485          ;1;346.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='596;6/7/2002;46485          ;1;776.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='597;2/15/1999;46485          ;1;892.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2352;2/15/1999;46485          ;1;367.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='663;2/15/1999;46485          ;1;765.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;2/15/1999;13051          ;1;585.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2262;5/31/2002;45359          ;1;299.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='683;2/15/1999;45359          ;1;788;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1009;4/12/2003;45359          ;1;99.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2263;5/31/2002;45359          ;1;299.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2277;5/31/2002;45359          ;3;929.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;1/15/1999;45359          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;45359          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='488;2/15/1999;45359          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='761;6/11/2003;45359          ;1;173.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2280;5/31/2002;50767          ;1;170.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;2/15/1999;50767          ;1;314.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;50767          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;50767          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2396;5/31/2002;50767          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2047;3/15/1999;50767          ;1;377.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2373;5/31/2002;50767          ;1;556.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;5/31/2002;50767          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2359;5/31/2002;50767          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;3/15/1999;50767          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2396;6/7/2002;50767          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2235;5/31/2002;13059          ;1;70.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2255;5/31/2002;13059          ;1;60.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='663;2/15/1999;47051          ;1;765.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;4/11/2003;47051          ;1;850.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2352;3/15/1999;47051          ;1;388.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='488;3/15/1999;47051          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1000;6/10/2003;47051          ;1;89.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;52159          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='769;2/15/1999;52159          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2064;3/15/1999;52159          ;1;488.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;1/15/1999;52159          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;5/31/2002;52159          ;1;945;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='981;6/7/2002;52159          ;1;157.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2332;6/7/2002;52159          ;1;367.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='940;6/8/2002;52159          ;1;687.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2282;1/15/1999;52159          ;1;304.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;52159          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='551;4/10/2003;52159          ;1;922.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1131;6/4/2002;52159          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='599;2/15/1999;52159          ;1;753.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;2/15/1999;52159          ;2;692.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1990;2/15/1999;52159          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='770;2/15/1999;52159          ;1;257.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2277;2/15/1999;52159          ;1;251.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='740;6/7/2002;13089          ;1;173.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='739;6/7/2002;13089          ;1;173.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1065;6/3/2002;13089          ;1;304.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1066;6/3/2002;13089          ;1;304.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1086;6/4/2002;13089          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1085;6/4/2002;13089          ;1;84;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='767;2/15/1999;46145          ;1;105;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1045;3/15/1999;46145          ;1;207.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;2/15/1999;46145          ;1;105;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;4/11/2003;13129          ;1;918.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;1/15/1999;13129          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1065;1/15/1999;13129          ;1;296.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='464;6/3/2002;13129          ;1;866.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;2/15/1999;46537          ;1;301.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;6/3/2002;46537          ;1;429.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;6/3/2002;46537          ;1;480.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;3/15/1999;46537          ;3;2910.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1017;5/31/2002;46537          ;1;262.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='906;6/7/2002;46537          ;1;419.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;46537          ;3;2910.6;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='687;2/15/1999;46537          ;1;446;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='443;2/15/1999;46537          ;1;790.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;46537          ;1;461.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='663;2/15/1999;46537          ;1;765.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='989;2/15/1999;47877          ;1;451.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1008;3/15/1999;47877          ;1;236.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1008;2/15/1999;46483          ;1;236.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='599;2/15/1999;46483          ;3;2260.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1949;2/15/1999;46483          ;2;593.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;3/15/1999;46483          ;1;801.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2064;4/11/2003;46483          ;1;496.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1202;6/3/2002;46483          ;1;619.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;4/14/2003;13159          ;1;494.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2234;5/31/2002;13159          ;2;141.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='400;3/15/1999;13159          ;1;683.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2352;6/7/2002;13159          ;1;367.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;2/15/1999;13159          ;1;857.1;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='550;2/15/1999;13159          ;1;404;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;13159          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1157;2/15/1999;47443          ;1;377.9;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='400;1/15/1999;47443          ;1;683.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='499;3/15/1999;47443          ;1;846.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='631;1/15/1999;47443          ;1;346.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2083;2/15/1999;50999          ;1;309.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;50999          ;1;970.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;3/15/1999;50999          ;2;829.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1909;3/15/1999;50999          ;1;199.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;3/15/1999;50999          ;1;815.3;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='785;4/10/2003;50999          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='786;4/10/2003;50999          ;1;57.7;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;5/31/2002;50999          ;1;430.4;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2400;6/3/2002;50999          ;1;94.5;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;50999          ;1;778.8;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2295;5/31/2002;13189          ;1;887.2;Germany'),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;3/15/1999;13189          ;1;461.7;Germany'),
# ...
#  Row(ProductID;Date;Zip;Units;Revenue;Country='443;4/11/2003;7760           ;1;851.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2254;2/15/1999;7760           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='645;1/15/1999;7760           ;1;746.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1005;1/15/1999;7760           ;1;107.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;1/15/1999;7760           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1106;2/15/1999;7760           ;1;246.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1132;2/15/1999;7760           ;1;630;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1105;2/15/1999;7760           ;1;246.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2255;2/15/1999;7760           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1911;3/15/1999;7760           ;1;244.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1157;1/15/1999;2680           ;1;377.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1046;1/15/1999;2710           ;1;99.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='952;5/31/2002;2710           ;1;262.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;5/31/2002;7540           ;1;330.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='838;2/15/1999;7540           ;1;934.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;1/15/1999;2729           ;1;346.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2282;1/15/1999;2729           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='728;1/15/1999;2729           ;1;63;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='852;3/15/1999;2729           ;1;745.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;4/12/2003;2729           ;1;430.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='976;4/12/2003;2729           ;1;325.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2074;2/15/1999;2729           ;1;328.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1148;6/3/2002;2729           ;1;314.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;2729           ;1;778.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;2729           ;1;801.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1489;2/15/1999;2729           ;1;262.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='604;2/15/1999;2729           ;1;461.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1215;6/3/2002;8029           ;1;356.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1131;2/15/1999;8029           ;1;419.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='728;1/15/1999;2730           ;1;63;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='681;1/15/1999;2730           ;1;629.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1956;1/15/1999;2730           ;2;307.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2284;1/15/1999;2730           ;1;293.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;1/15/1999;2730           ;1;105;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='716;4/12/2003;2730           ;1;152.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='785;4/12/2003;2730           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='715;4/12/2003;2730           ;1;152.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='915;4/12/2003;2730           ;1;556.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='786;4/12/2003;2730           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='981;4/12/2003;2730           ;1;157.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;1/15/1999;2730           ;1;280.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='727;1/15/1999;2730           ;1;63;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;3/15/1999;2730           ;1;296.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='606;3/15/1999;2730           ;2;629.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2380;4/11/2003;2739           ;1;293.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;1/15/1999;2739           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1957;1/15/1999;2739           ;1;153.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2388;4/10/2003;2739           ;1;309.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='493;4/10/2003;2760           ;1;969.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;3/15/1999;2760           ;1;970.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2210;3/15/1999;2770           ;1;107.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1080;2/15/1999;2770           ;1;262.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1079;2/15/1999;2770           ;1;262.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1169;2/15/1999;2770           ;1;419.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='574;6/4/2002;8520           ;1;869.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='962;2/15/1999;8520           ;1;525;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2277;2/15/1999;8520           ;1;251.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1927;5/31/2002;8520           ;1;99.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2388;2/15/1999;8520           ;1;309.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2070;2/15/1999;8520           ;2;1039.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='761;4/12/2003;2810           ;1;173.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='762;4/12/2003;2810           ;1;173.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2282;2/15/1999;7918           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2282;2/15/1999;9009           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;6/8/2002;9009           ;1;918.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='966;5/31/2002;2840           ;1;472.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='728;1/15/1999;2840           ;1;63;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2284;2/15/1999;9340           ;1;293.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1518;2/15/1999;9340           ;1;141.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;5/31/2002;9340           ;1;120.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='767;2/15/1999;9340           ;1;105;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;2/15/1999;9340           ;1;105;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;2/15/1999;9340           ;1;301.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1517;2/15/1999;9340           ;1;141.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1346;1/15/1999;2860           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='932;3/15/1999;2860           ;1;430.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1345;1/15/1999;2860           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2211;2/15/1999;2860           ;1;107.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='671;4/10/2003;2860           ;1;944.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2210;2/15/1999;2860           ;1;107.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='910;5/31/2002;2920           ;1;430.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2211;2/15/1999;2920           ;1;107.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;1/15/1999;2940           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1948;3/15/1999;2940           ;1;296.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1949;3/15/1999;2940           ;1;296.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='767;2/15/1999;7739           ;1;102.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;2/15/1999;7739           ;1;102.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2282;1/15/1999;2980           ;1;304.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='559;6/5/2002;2980           ;1;624.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1185;2/15/1999;7950           ;1;419.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1053;2/15/1999;7950           ;1;251.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1957;2/15/1999;8040           ;1;153.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1956;2/15/1999;8040           ;1;153.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2254;1/15/1999;4000           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2192;4/11/2003;4000           ;1;209.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2255;1/15/1999;4000           ;1;57.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2046;6/3/2002;4000           ;1;433.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1169;1/15/1999;4009           ;1;435.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1430;1/15/1999;4009           ;1;283.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2380;5/31/2002;4009           ;1;293.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2064;4/10/2003;4009           ;1;496.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2235;2/15/1999;9239           ;1;65.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2234;2/15/1999;9239           ;1;65.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='757;1/15/1999;4010           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='758;1/15/1999;4010           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1116;1/15/1999;4020           ;1;251.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='433;4/11/2003;4020           ;1;880.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='120;2/15/1999;4020           ;1;829.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='753;3/15/1999;4020           ;1;244.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='400;2/15/1999;9250           ;1;683.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='976;5/31/2002;9250           ;1;314.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='396;6/7/2002;9250           ;1;892.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='635;4/9/2003;4100           ;1;881.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2082;4/10/2003;4100           ;1;335.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;4/12/2003;4100           ;1;320.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;4100           ;1;778.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='676;2/15/1999;4100           ;1;801.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;2/15/1999;4100           ;1;535.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2359;4/10/2003;4100           ;1;430.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='475;2/15/1999;4100           ;1;970.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='491;2/15/1999;4129           ;1;815.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='681;2/15/1999;7790           ;1;629.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2255;6/7/2002;7790           ;1;60.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2254;6/7/2002;7790           ;1;60.3;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2022;5/31/2002;4210           ;1;230.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2054;5/31/2002;4210           ;1;546;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2284;1/15/1999;4210           ;1;293.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='826;5/31/2002;4210           ;1;945;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='725;2/15/1999;9080           ;1;115.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2340;2/15/1999;9080           ;1;461.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;2/15/1999;9080           ;1;115.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='981;5/31/2002;4230           ;1;157.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='727;2/15/1999;9320           ;1;68.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='728;2/15/1999;9320           ;1;68.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='837;2/15/1999;9320           ;1;813.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='768;1/15/1999;4239           ;1;105;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1110;1/15/1999;4240           ;1;209.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='797;3/15/1999;4240           ;1;301.8;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1116;2/15/1999;9369           ;1;251.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2359;5/31/2002;9369           ;2;860.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1112;2/15/1999;9369           ;1;116.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1111;2/15/1999;9369           ;1;116.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='754;1/15/1999;4259           ;1;244.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2331;1/15/1999;4259           ;1;535.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2056;2/15/1999;4259           ;1;325.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='964;4/10/2003;4269           ;1;330.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='757;2/15/1999;4269           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2057;1/15/1999;4270           ;1;472.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1965;4/10/2003;4270           ;1;89.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='740;2/15/1999;4270           ;1;170.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1964;4/10/2003;4270           ;1;89.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1229;2/15/1999;4270           ;1;236.2;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='2064;5/31/2002;4280           ;1;496.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='726;1/15/1999;4280           ;1;115.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1911;2/15/1999;4280           ;1;244.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1085;6/3/2002;4280           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1086;6/3/2002;4280           ;1;84;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='990;3/15/1999;4280           ;1;503.9;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1960;2/15/1999;7560           ;1;97.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='573;1/15/1999;7560           ;1;280.6;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1961;2/15/1999;7560           ;1;97.1;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='645;2/15/1999;7560           ;1;746.5;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1122;2/15/1999;7560           ;1;157.4;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='1132;2/15/1999;7560           ;1;630;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;2/15/1999;7560           ;2;1557.7;Mexico '),
#  Row(ProductID;Date;Zip;Units;Revenue;Country='609;6/4/2002;4309           ;1;829.2;Mexico '),
#  ...]

# %% [markdown]
# ### CREAR UN RDD A PARTIR DE UNA LISTA
# Podemos crear un RDD directamente desde una lista de Python utilizando el método parallelize del SparkContext. Esto distribuirá la lista a través de los nodos del clúster.

# %%
lista = [1, 2, 3, 4, 5]
rdd = sc.parallelize(lista)
rdd.collect()
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# En algunos ejemplos se ha usado SparkSession y en otros SparkContext a la hora de crear RDD:
# * SparkSession se utiliza para leer archivos CSV debido a que esta funcionalidad está integrada en la API de DataFrame, que es más adecuada para manejar datos estructurados y ofrece más características para la lectura y manipulación de estos datos. Por otro lado,
# * SparkContext se utiliza para crear RDDs de formas más básicas y directas, como a partir de archivos de texto o listas, donde no se necesitan las capacidades avanzadas de la API de DataFrame.

# %% [markdown]
# ## ACCIONES
# Las acciones son operaciones en RDD que se ejecutan inmediatamente.
#
# Mientras que las transformaciones devuelven otro RDD, las acciones devuelven estructuras de datos nativas.
#
# Acciones frecuentes en RDD:
# * collect
# * count
# * first
# * take
# * takeSample
# * takeOrdered
# * reduce
#
# [Más información sobre las acciones de Spark](https://spark.apache.org/docs/latest/rdd-programming-guide.html#actions)

# %% [markdown]
# ### collect
# Devuelve todos los elementos para el RDD dado.

# %%
rdd = sc.parallelize([1, 2, 3, 4, 2])
rdd.collect()
# Out:
# [1, 2, 3, 4, 2]

# %% [markdown]
# La acción collect duvuelve todos los datos que se distribuyen entre los diferentes trabajadores del clúster. Todos los datos viajan a través de la red de los trabajadores al master o driver y éste los tiene que almacenar.
# Si estamos trabajando con una gran cantidad de datos esto penalizará el rendimiento de nuestra aplicación.

# %% [markdown]
# ### count
# Devuelve el número de elementos en el RDD dado.

# %%
rdd.count()
# Out:
# 5

# %% [markdown]
# ### first
# Devuelve el primer elemento del RDD dado.

# %%
rdd.first()
# Out:
# 1

# %% [markdown]
# ### take
# Devuelve los primeros N elementos, donde N es un parámetro que le tenemos que indicar.

# %%
rdd.take(3)
# Out:
# [1, 2, 3]

# %% [markdown]
# ### takeSample
# Devuelve una muestra con el número de elementos que le indiquemos.

# %%
rdd.takeSample(False, 3)
# Out:
# [4, 5, 3]

# %% [markdown]
# El primer parámetro indica si se pueden repetir los elementos de la muestra y el segundo fija la cantidad de elementos a devolver

# %% [markdown]
# ### takeOrdered
# Devuelve los primero N elementos, donde N es un parámetro que le tenemos que indicar, después de ordenarlos según su orden natural o según cualquier otro orden que le indiquemos.

# %%
rdd.takeOrdered(3)
# Out:
# [1, 2, 3]

# %%
rdd.takeOrdered(3, lambda x: -x)
# Out:
# [5, 4, 3]

# %% [markdown]
# Hay que tener cuidado si el conjunto de datos es muy grande, porque tanto take, como takeSample y takeOrdered  llevarán todos los datos a memoria.

# %% [markdown]
# ### reduce
# Combina los elementos de un RDD (Resilient Distributed Dataset) de manera que se obtenga un único valor. Funciona aplicando una función que toma dos argumentos y devuelve un nuevo valor, de forma iterativa, a los elementos del RDD.

# %%
rdd = sc.parallelize([1, 2, 3, 4, 5])

def sumar(a, b):
    return a + b

suma_total = rdd.reduce(sumar)
suma_total
# Out:
# 15

# %% [markdown]
# ## TRANSFORMACIONES
# En Spark, las estructuras de datos son inmutables, de manera que una vez creadas no se pueden modificar. Para poder modificar un RDD/DataFrame/Dataset, hace falta realizar una transformación.
#
# Todas las transformaciones en Spark se evalúan de manera perezosa (**lazy evaluation**), de manera que los resultados no se computan inmediatamente, sino que se retrasa el cálculo hasta que el valor sea necesario. Para ello, se van almacenando los pasos necesarios y se ejecutan únicamente cuando una acción requiere devolver un resultado al driver. Este diseño facilita un mejor rendimiento.
#
# Así pues, las acciones provocan la evaluación de todas las transformaciones previas que se habían evaluado de forma perezosa y estaban a la espera.
#
# Por defecto, cada transformación se puede recalcular cada vez que se ejecute una acción. Sin embargo, podemos persistir un RDD en memoria mediante los métodos persist (o cache ), de manera que Spark mantendrá los datos para un posterior acceso más eficiente. También podemos persistir RDD en disco o replicarlo en múltiples nodos.
#
# Existen dos tipos de transformaciones, dependiendo de las dependencias entre las particiones de datos:
# * Transformaciones Narrow: consisten en dependencias estrechas en las que cada partición de entrada contribuye a una única partición de salida.
# * Transformaciones Wide: consisten en dependencias anchas de manera que varias particiones de entrada contribuyen a muchas otras particiones de salida, es decir, cada partición de salida depende de diferentes particiones de entrada. Este proceso también se conoce como shuffle, ya que Spark baraja los datos entre las particiones del clúster.
#
# ![Ejemplo](Datos/transformaciones.jpg "Título de la imagen")
#
# Transformaciones frecuentes en RDD:
# * map
# * filter
# * flatMap
# * distinct
# * union
# * intersection
# * subtract
#
# [Más información sobre las transformaciones de Spark](https://spark.apache.org/docs/latest/rdd-programming-guide.html#transformations)

# %% [markdown]
# ### map
# Aplica la función recibida a cada elemento del RDD, de manera que se puede añadir una nueva columna, modificar una existente, etc...

# %%
rdd = sc.parallelize([1, 2, 3, 4, 5])
rdd = rdd.map(lambda x: x * 2)
rdd.collect()
# Out:
# [2, 4, 6, 8, 10]

# %%
rddEmpleados = sc.textFile("Datos/empleados.txt")
rddEmpleados.collect()
# Out:
# ['Michael|Montreal,Toronto|Male,30|DB:80|Product:Developer Lead',
#  'Will|Montreal|Male,35|Perl:85|Product:Lead,Test:Lead',
#  'Shelley|New York|Female,27|Python:80|Test:Lead,COE:Architect',
#  'Lucy|Vancouver|Female,57|Sales:89,HR:94|Sales:Lead']

# %%
for empleado in rddEmpleados.collect():
    print(empleado)
# Out:
# Michael|Montreal,Toronto|Male,30|DB:80|Product:Developer Lead
# Will|Montreal|Male,35|Perl:85|Product:Lead,Test:Lead
# Shelley|New York|Female,27|Python:80|Test:Lead,COE:Architect
# Lucy|Vancouver|Female,57|Sales:89,HR:94|Sales:Lead

# %%
rdd = rddEmpleados.map(len)
rdd.collect()
# Out:
# [61, 52, 60, 50]

# %% [markdown]
# ### flatMap
# Es muy similar a la anterior, pero en vez de devolver una lista con un elemento por cada entrada, devuelve una única lista deshaciendo las colecciones en elementos individuales

# %%
rdd= rddEmpleados.flatMap(lambda x: x.split("|"))
rdd.collect()
# Out:
# ['Michael',
#  'Montreal,Toronto',
#  'Male,30',
#  'DB:80',
#  'Product:Developer Lead',
#  'Will',
#  'Montreal',
#  'Male,35',
#  'Perl:85',
#  'Product:Lead,Test:Lead',
#  'Shelley',
#  'New York',
#  'Female,27',
#  'Python:80',
#  'Test:Lead,COE:Architect',
#  'Lucy',
#  'Vancouver',
#  'Female,57',
#  'Sales:89,HR:94',
#  'Sales:Lead']

# %%
rddLista = sc.parallelize([5, 2, 3, 4, 2])
rdd = rddLista.flatMap(lambda x: range(1, x))
rdd.collect()
# Out:
# [1, 2, 3, 4, 1, 1, 2, 1, 2, 3, 1]

# %% [markdown]
# ### filter
# Permite filtrar los elementos que cumplen una condición.

# %%
rddLista = sc.parallelize([1, 2, 3, 4, 5])
rdd = rddLista.filter(lambda x: x % 2 == 0)
rdd.collect()
# Out:
# [2, 4]

# %% [markdown]
# También podemos anidar diferentes transformaciones. Para este ejemplo, vamos a crear tuplas formadas por un número y su cuadrado, y luego quitar los que no coincide el número con su cuadrado (sólo coinciden el 0 y el 1), y luego aplanarlo en una lista.

# %%
rdd10 = sc.parallelize(range(10 + 1))
rdd = (
    rdd10.map(lambda x: (x, x ** 2))
    .filter(lambda x: (x[0] != x[1]))
    .flatMap(lambda x: x)
)
rdd.collect()
# Out:
# [2, 4, 3, 9, 4, 16, 5, 25, 6, 36, 7, 49, 8, 64, 9, 81, 10, 100]

# %% [markdown]
# Veamos otro ejemplo. Retomamos los datos de los empleados y si queremos filtrar los empleados que son hombres, primero separamos por las | y nos quedamos con el tercer elemento que contiene el sexo y la edad. A continuación, separamos por la coma para quedarnos con el sexo en la posición 0 y la edad en el 1, y comparamos con el valor deseado.

# %%
hombres = rddEmpleados.filter(lambda x: x.split("|")[2].split(",")[0] == "Male")
hombres.collect()
# Out:
# ['Michael|Montreal,Toronto|Male,30|DB:80|Product:Developer Lead',
#  'Will|Montreal|Male,35|Perl:85|Product:Lead,Test:Lead']

# %% [markdown]
# ### distinct
# Elimina los elementos repetidos

# %%
rddLista = sc.parallelize([1, 1, 2, 2, 3, 4, 5])
rdd = rddLista.distinct()
rdd.collect()
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### union
# Une dos rdd en uno

# %%
rdd1 = sc.parallelize([1, 2, 3, 4, 5])
rdd2 = sc.parallelize([5, 6, 7, 8])
rddUnion = rdd1.union(rdd2)
rddUnion.collect()
# Out:
# [1, 2, 3, 4, 5, 5, 6, 7, 8]

# %% [markdown]
# ### intersection
# Devuelve un rdd con los elementos en común de dos rdd

# %%
rdd1 = sc.parallelize([1, 2, 3, 4])
rdd2 = sc.parallelize([3, 4, 5, 6])
rddIntersection = rdd1.intersection(rdd2)
rddIntersection.collect()
# Out:
# [3, 4]

# %% [markdown]
# ### subtract
# Devuelve los elementos de un rdd que no están en el segundo rdd

# %%
rdd1 = sc.parallelize([1, 2, 3, 4])
rdd2 = sc.parallelize([3, 4, 5, 6])
rddSubtract = rdd1.subtract(rdd2)
rddSubtract.collect()
# Out:
# [1, 2]

# %% [markdown]
# ## RDD DE PARES
# Una técnica muy común a la hora de trabajar con RDD es hacerlo con elementos que tienen el formato (clave, valor), pudiendo las claves y los valores ser de cualquier tipo.

# %% [markdown]
# ### CREACIÓN DE UN RDD DE PARES

# %% [markdown]
# #### A PARTIR DE UNA LISTA DE TUPLAS

# %%
listaTuplas = [(1, "a"), (2, "b"), (3, "c"), (4, "d")]
rddTuplas = sc.parallelize(listaTuplas)

# %% [markdown]
# #### zip
# Une dos RDDs del mismo tamaño

# %%
lista1 = ['a','b','c','e','f','g','h']
lista2 = [4, 5, 6, 7, 8, 9, 10]
rddZip = sc.parallelize(lista1).zip(sc.parallelize(lista2))
rddZip.collect()
# Out:
# [('a', 4), ('b', 5), ('c', 6), ('e', 7), ('f', 8), ('g', 9), ('h', 10)]

# %%
rddZipSecuencia = sc.parallelize(zip(lista1, range(len(lista1))))
rddZipSecuencia.collect()
# Out:
# [('a', 0), ('b', 1), ('c', 2), ('e', 3), ('f', 4), ('g', 5), ('h', 6)]

# %% [markdown]
# Otros métodos relacionados son zipWithIndex y zipWithUniqueId

# %%
lista = ['a', 'b', 'c', 'd']
rdd = sc.parallelize(lista)
rddZipWithIndex = rdd.zipWithIndex()
rddZipWithIndex.collect()
# Out:
# [('a', 0), ('b', 1), ('c', 2), ('d', 3)]

# %%
rdd = sc.parallelize(['a', 'b', 'c', 'd'])
rddWithUniqueId = rdd.zipWithUniqueId()
rddWithUniqueId.collect()
# Out:
# [('a', 3), ('b', 7), ('c', 11), ('d', 15)]

# %% [markdown]
# #### map
# Asigna a cada elemento un valor o cálculo sobre él mismo

# %%
lista = ["Hola", "Adiós", "Hasta luego"]
rddMap = sc.parallelize(lista).map(lambda x: (x, len(x)))
rddMap.collect()
# Out:
# [('Hola', 4), ('Adiós', 5), ('Hasta luego', 11)]

# %% [markdown]
# #### keyBy
# Permite crear las claves a partir de cada elemento

# %%
rddKeyBy = sc.parallelize(lista).keyBy(lambda x: x[0])
rddKeyBy.collect()
# Out:
# [('H', 'Hola'), ('A', 'Adiós'), ('H', 'Hasta luego')]

# %% [markdown]
# ### TRASNFORMACIONES

# %% [markdown]
# #### keys
# Devuelve las claves

# %%
listaTuplas = [("a", 1), ("z", 3), ("b", 4), ("c", 3), ("a", 4)]
rddTuplas = sc.parallelize(listaTuplas)
claves = rddTuplas.keys()
claves.collect()
# Out:
# ['a', 'z', 'b', 'c', 'a']

# %% [markdown]
# #### values
# Devuelve los valores

# %%
valores = rddTuplas.values()
valores.collect()
# Out:
# [1, 3, 4, 3, 4]

# %% [markdown]
# #### mapValues
# Aplica una función sobre los valores

# %%
rddMapValues = rddTuplas.mapValues(lambda x: (x, x*2))
rddMapValues.collect()
# Out:
# [('a', (1, 2)), ('z', (3, 6)), ('b', (4, 8)), ('c', (3, 6)), ('a', (4, 8))]

# %% [markdown]
# #### flatMapValues
# Aplica la función sobre los valores y los aplana

# %%
rddFlatMapValues = rddTuplas.flatMapValues(lambda x: (x, x * 2))
rddFlatMapValues.collect()
# Out:
# [('a', 1),
#  ('a', 2),
#  ('z', 3),
#  ('z', 6),
#  ('b', 4),
#  ('b', 8),
#  ('c', 3),
#  ('c', 6),
#  ('a', 4),
#  ('a', 8)]

# %% [markdown]
# #### reduceByKey
# Esta función reduce los pares agrupando por las claves y aplicando la funcion indicada a los values.

# %%
rddSales = sc.textFile("Datos/pdi_sales_small.csv")
rddSales.take(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b003d8d89c97> in <cell line: 1>()
# ----> 1 rddSales = sc.textFile("Datos/pdi_sales_small.csv")
#       2 rddSales.take(3)
#
# NameError: name 'sc' is not defined

# %%
parPais1 = rddSales.map(lambda x: (x.split(";")[-1].strip(), 1))
parPais1.collect()
# Out:
# [('Country', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ...]

# %% [markdown]
# Hemos creado un RDD de pares compuesto por el nombre del país y el número uno, para luego en la fase de reducción sumar estos valores. Pero si nos fijamos, el archivo csv contiene el encabezado con los datos, el cual debemos quitar

# %%
header = parPais1.first()
parPais1SinHeader = parPais1.filter(lambda linea: linea != header)
parPais1SinHeader.collect()
# Out:
# [('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Germany', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ('Mexico', 1),
#  ...]

# %% [markdown]
# Y finalmente, ya podemos reducir por la clave:

# %%
paisesTotal = parPais1SinHeader.reduceByKey(lambda a, b: a + b)
paisesTotal.collect()
# Out:
# [('Mexico', 30060), ('France', 30060), ('Germany', 30059), ('Canada', 30060)]

# %%
pairs = [ ("a", 5), ("b", 7), ("c", 2), ("a", 3), ("b", 1), ("c", 4)]
pair_rdd = sc.parallelize(pairs)
output = pair_rdd.reduceByKey(lambda x, y : x + y)
result = output.collect()
print(*result, sep='\n')
# Out:
# ('b', 8)
# ('c', 6)
# ('a', 8)

# %% [markdown]
# Veamos otro ejemplo, en este caso vamos a calcular el total de unidades vendidas por país, de manera que vamos a coger el nombre del país (Country) y las unidades (Units) vendidas:

# %%
paisesUnidades = rddSales.map(lambda x: (x.split(";")[-1].strip(), x.split(";")[3]))
header = paisesUnidades.first()
paisesUnidadesSinHeader = paisesUnidades.filter(lambda linea: linea != header)
paisesUnidadesInt = paisesUnidadesSinHeader.map(lambda x: (x[0], float(x[1])))
paisesTotalUnidades = paisesUnidadesInt.reduceByKey(lambda a, b: a + b)
paisesTotalUnidades.collect()
# Out:
# [('Mexico', 10588066.300000923),
#  ('France', 9453441.700000618),
#  ('Germany', 31746.0),
#  ('Canada', 31148.0)]

# %% [markdown]
# #### groupByKey
# Esta función es otra función ByKey que puede operar en un par (clave, valor) RDD pero esto solo agrupará los valores basados en las claves.

# %%
ventas = rddSales.map(lambda x: (x.split(";")[-1].strip(), x.split(";")))
header = ventas.first()
ventasSinHeader = ventas.filter(lambda linea: linea != header)
paisesAgrupados = ventasSinHeader.groupByKey()
paisesAgrupados.collect()
# Out:
# [('Mexico', <pyspark.resultiterable.ResultIterable at 0x131bc6740>),
#  ('France', <pyspark.resultiterable.ResultIterable at 0x131987dc0>),
#  ('Germany', <pyspark.resultiterable.ResultIterable at 0x1319872b0>),
#  ('Canada', <pyspark.resultiterable.ResultIterable at 0x1319879a0>)]

# %% [markdown]
# Obtendremos para cada país, un iterable con todos sus datos, asi que podemos transformar los iterables a una lista:

# %%
paisesAgrupadosLista = paisesAgrupados.map(lambda x: (x[0], list(x[1])))
paisesAgrupadosLista.collect()
# Out:
# [('Mexico',
#   [['2235', '1/15/1999', '86501', '65.6', 'Mexico '],
#    ['837', '2/15/1999', '86501', '840', 'Mexico '],
#    ['491', '2/15/1999', '86501', '815.3', 'Mexico '],
#    ['426', '5/31/2002', '86501', '843.1', 'Mexico '],
#    ['400', '6/6/2002', '86501', '734.7', 'Mexico '],
#    ['1131', '2/15/1999', '86501', '419.9', 'Mexico '],
#    ['2277', '3/15/1999', '86501', '251.9', 'Mexico '],
#    ['491', '3/15/1999', '86501', '815.3', 'Mexico '],
#    ['467', '6/8/2002', '86501', '900.6', 'Mexico '],
#    ['565', '4/12/2003', '20001', '890.7', 'Mexico '],
#    ['604', '4/12/2003', '20001', '494.8', 'Mexico '],
#    ['940', '3/15/1999', '20001', '687.7', 'Mexico '],
#    ['2277', '1/15/1999', '86401', '251.9', 'Mexico '],
#    ['739', '1/15/1999', '20081', '170.6', 'Mexico '],
#    ['2188', '1/15/1999', '20081', '233.6', 'Mexico '],
#    ['1894', '1/15/1999', '20081', '682.2', 'Mexico '],
#    ['757', '4/11/2003', '20081', '73.5', 'Mexico '],
#    ['758', '4/11/2003', '20081', '73.5', 'Mexico '],
#    ['2373', '3/15/1999', '20081', '551.2', 'Mexico '],
#    ['606', '1/15/1999', '88301', '314.7', 'Mexico '],
#    ['2082', '4/10/2003', '88301', '335.9', 'Mexico '],
#    ['2284', '2/15/1999', '88301', '293.9', 'Mexico '],
#    ['2055', '6/3/2002', '20091', '569.6', 'Mexico '],
#    ['396', '3/15/1999', '20091', '857.1', 'Mexico '],
#    ['658', '1/15/1999', '91301', '902.7', 'Mexico '],
#    ['992', '4/11/2003', '91301', '278.2', 'Mexico '],
#    ['2282', '1/15/1999', '91301', '304.4', 'Mexico '],
#    ['2255', '5/31/2002', '91301', '60.3', 'Mexico '],
#    ['1182', '2/15/1999', '91301', '157.4', 'Mexico '],
#    ['2056', '2/15/1999', '91301', '325.4', 'Mexico '],
#    ['2254', '5/31/2002', '91301', '60.3', 'Mexico '],
#    ['671', '6/3/2002', '91301', '892.2', 'Mexico '],
#    ['687', '1/15/1999', '91601', '446', 'Mexico '],
#    ['599', '2/15/1999', '91601', '753.6', 'Mexico '],
#    ['1927', '5/31/2002', '91601', '99.7', 'Mexico '],
#    ['1926', '5/31/2002', '91601', '99.7', 'Mexico '],
#    ['2074', '5/31/2002', '91601', '335.9', 'Mexico '],
#    ['683', '3/15/1999', '20201', '788', 'Mexico '],
#    ['713', '1/15/1999', '77081', '160.1', 'Mexico '],
#    ['1116', '2/15/1999', '77081', '251.9', 'Mexico '],
#    ['725', '1/15/1999', '94101', '115.5', 'Mexico '],
#    ['2388', '2/15/1999', '94101', '309.7', 'Mexico '],
#    ['2045', '2/15/1999', '94101', '409.4', 'Mexico '],
#    ['2234', '2/15/1999', '94101', '65.6', 'Mexico '],
#    ['726', '1/15/1999', '94101', '115.5', 'Mexico '],
#    ['758', '1/15/1999', '94101', '84', 'Mexico '],
#    ['767', '1/15/1999', '94101', '105', 'Mexico '],
#    ['2235', '2/15/1999', '94101', '65.6', 'Mexico '],
#    ['726', '1/15/1999', '87301', '115.5', 'Mexico '],
#    ['728', '2/15/1999', '87301', '63', 'Mexico '],
#    ['725', '1/15/1999', '87301', '115.5', 'Mexico '],
#    ['727', '2/15/1999', '87301', '63', 'Mexico '],
#    ['433', '1/15/1999', '20601', '804.3', 'Mexico '],
#    ['728', '1/15/1999', '80101', '63', 'Mexico '],
#    ['1990', '2/15/1999', '80101', '257.2', 'Mexico '],
#    ['727', '1/15/1999', '80101', '63', 'Mexico '],
#    ['1116', '1/15/1999', '80101', '251.9', 'Mexico '],
#    ['2083', '3/15/1999', '80101', '309.7', 'Mexico '],
#    ['981', '1/15/1999', '20701', '157.4', 'Mexico '],
#    ['2235', '1/15/1999', '20701', '65.6', 'Mexico '],
#    ['740', '1/15/1999', '77401', '170.6', 'Mexico '],
#    ['739', '1/15/1999', '77401', '170.6', 'Mexico '],
#    ['2211', '1/15/1999', '77401', '107.6', 'Mexico '],
#    ['2234', '1/15/1999', '77401', '65.6', 'Mexico '],
#    ['609', '2/15/1999', '77401', '778.8', 'Mexico '],
#    ['2284', '3/15/1999', '77401', '293.9', 'Mexico '],
#    ['757', '1/15/1999', '75802', '167.9', 'Mexico '],
#    ['1173', '2/15/1999', '75801', '525', 'Mexico '],
#    ['491', '2/15/1999', '75802', '1630.7', 'Mexico '],
#    ['574', '6/3/2002', '75801', '869.1', 'Mexico '],
#    ['443', '2/15/1999', '75801', '790.9', 'Mexico '],
#    ['597', '2/15/1999', '75801', '892.2', 'Mexico '],
#    ['433', '1/15/1999', '75801', '804.3', 'Mexico '],
#    ['491', '1/15/1999', '75802', '1630.7', 'Mexico '],
#    ['767', '1/15/1999', '75801', '105', 'Mexico '],
#    ['1975', '1/15/1999', '75801', '52.5', 'Mexico '],
#    ['2270', '5/31/2002', '75801', '314.9', 'Mexico '],
#    ['2094', '2/15/1999', '75801', '433.1', 'Mexico '],
#    ['2277', '2/15/1999', '75801', '251.9', 'Mexico '],
#    ['1185', '2/15/1999', '75801', '419.9', 'Mexico '],
#    ['426', '2/15/1999', '75801', '795.1', 'Mexico '],
#    ['533', '6/3/2002', '75801', '524.7', 'Mexico '],
#    ['676', '3/15/1999', '75802', '1603.9', 'Mexico '],
#    ['758', '1/15/1999', '94001', '84', 'Mexico '],
#    ['2373', '4/10/2003', '94001', '619.5', 'Mexico '],
#    ['1920', '6/4/2002', '94001', '262.4', 'Mexico '],
#    ['2211', '1/15/1999', '94001', '107.6', 'Mexico '],
#    ['1122', '2/15/1999', '94001', '157.4', 'Mexico '],
#    ['604', '2/15/1999', '94001', '461.7', 'Mexico '],
#    ['772', '1/15/1999', '93301', '165.3', 'Mexico '],
#    ['979', '1/15/1999', '81881', '393.7', 'Mexico '],
#    ['631', '2/15/1999', '21091', '346.2', 'Mexico '],
#    ['1120', '1/15/1999', '77291', '173.2', 'Mexico '],
#    ['606', '4/11/2003', '77291', '337.8', 'Mexico '],
#    ['2234', '2/15/1999', '77291', '65.6', 'Mexico '],
#    ['1916', '6/5/2002', '77291', '286.1', 'Mexico '],
#    ['2235', '2/15/1999', '77291', '65.6', 'Mexico '],
#    ['1517', '3/15/1999', '77291', '141.7', 'Mexico '],
#    ['728', '3/15/1999', '77291', '63', 'Mexico '],
#    ['499', '1/15/1999', '21101', '846.3', 'Mexico '],
#    ['730', '5/31/2002', '21101', '309.7', 'Mexico '],
#    ['823', '5/31/2002', '21101', '624.7', 'Mexico '],
#    ['826', '5/31/2002', '21101', '918.7', 'Mexico '],
#    ['2081', '1/15/1999', '21101', '220.4', 'Mexico '],
#    ['1065', '2/15/1999', '21101', '296.6', 'Mexico '],
#    ['2268', '3/15/1999', '21101', '309.7', 'Mexico '],
#    ['1990', '1/15/1999', '90101', '257.2', 'Mexico '],
#    ['559', '4/10/2003', '90101', '643.4', 'Mexico '],
#    ['1948', '1/15/1999', '90102', '593.1', 'Mexico '],
#    ['400', '1/15/1999', '90101', '683.8', 'Mexico '],
#    ['910', '2/15/1999', '90101', '414.7', 'Mexico '],
#    ['2192', '3/15/1999', '90101', '202.1', 'Mexico '],
#    ['2331', '1/15/1999', '78801', '535.5', 'Mexico '],
#    ['596', '2/15/1999', '78801', '746.5', 'Mexico '],
#    ['2016', '4/10/2003', '78801', '309.7', 'Mexico '],
#    ['964', '4/11/2003', '78801', '330.7', 'Mexico '],
#    ['580', '2/15/1999', '78801', '734.7', 'Mexico '],
#    ['1935', '5/31/2002', '78801', '136.4', 'Mexico '],
#    ['981', '2/15/1999', '78801', '157.4', 'Mexico '],
#    ['1133', '6/3/2002', '21251', '645.7', 'Mexico '],
#    ['193', '2/15/1999', '85001', '682', 'Mexico '],
#    ['2279', '2/15/1999', '85001', '165.3', 'Mexico '],
#    ['767', '1/15/1999', '85001', '105', 'Mexico '],
#    ['1116', '2/15/1999', '85001', '251.9', 'Mexico '],
#    ['726', '6/8/2002', '85001', '120.7', 'Mexico '],
#    ['725', '6/8/2002', '85001', '120.7', 'Mexico '],
#    ['433', '2/15/1999', '93001', '804.3', 'Mexico '],
#    ['491', '2/15/1999', '93001', '815.3', 'Mexico '],
#    ['1956', '2/15/1999', '93001', '153.8', 'Mexico '],
#    ['1957', '2/15/1999', '93001', '153.8', 'Mexico '],
#    ['2071', '5/31/2002', '93001', '346.4', 'Mexico '],
#    ['550', '2/15/1999', '93001', '404', 'Mexico '],
#    ['2083', '2/15/1999', '93001', '309.7', 'Mexico '],
#    ['758', '1/15/1999', '21282', '167.9', 'Mexico '],
#    ['757', '1/15/1999', '21282', '167.9', 'Mexico '],
#    ['2012', '3/15/1999', '21281', '377.9', 'Mexico '],
#    ['482', '2/15/1999', '92601', '672', 'Mexico '],
#    ['491', '4/12/2003', '21291', '890.7', 'Mexico '],
#    ['2094', '6/4/2002', '21291', '438.3', 'Mexico '],
#    ['727', '3/15/1999', '21291', '63', 'Mexico '],
#    ['901', '3/15/1999', '21291', '409.4', 'Mexico '],
#    ['532', '2/15/1999', '21401', '556.5', 'Mexico '],
#    ['604', '2/15/1999', '78001', '461.7', 'Mexico '],
#    ['550', '2/15/1999', '78002', '808', 'Mexico '],
#    ['318', '1/15/1999', '78001', '866', 'Mexico '],
#    ['573', '1/15/1999', '78001', '275.4', 'Mexico '],
#    ['2234', '1/15/1999', '78001', '65.6', 'Mexico '],
#    ['400', '2/15/1999', '78001', '683.8', 'Mexico '],
#    ['1436', '3/15/1999', '78001', '312.3', 'Mexico '],
#    ['2005', '3/15/1999', '78001', '299.2', 'Mexico '],
#    ['713', '2/15/1999', '75701', '160.1', 'Mexico '],
#    ['714', '2/15/1999', '75701', '160.1', 'Mexico '],
#    ['1182', '2/15/1999', '75701', '157.4', 'Mexico '],
#    ['797', '1/15/1999', '75701', '301.8', 'Mexico '],
#    ['1915', '5/31/2002', '75701', '467.2', 'Mexico '],
#    ['976', '5/31/2002', '75702', '629.9', 'Mexico '],
#    ['727', '1/15/1999', '75701', '63', 'Mexico '],
#    ['767', '2/15/1999', '75701', '105', 'Mexico '],
#    ['426', '3/15/1999', '75701', '795.1', 'Mexico '],
#    ['768', '2/15/1999', '75701', '105', 'Mexico '],
#    ['400', '4/12/2003', '21601', '772.3', 'Mexico '],
#    ['725', '2/15/1999', '93591', '115.5', 'Mexico '],
#    ['726', '2/15/1999', '93591', '115.5', 'Mexico '],
#    ['946', '5/31/2002', '21691', '708.7', 'Mexico '],
#    ['758', '1/15/1999', '21691', '84', 'Mexico '],
#    ['757', '3/15/1999', '21691', '84', 'Mexico '],
#    ['550', '2/15/1999', '21691', '404', 'Mexico '],
#    ['1045', '6/3/2002', '21691', '217.8', 'Mexico '],
#    ['1173', '2/15/1999', '21691', '525', 'Mexico '],
#    ['2081', '2/15/1999', '22002', '440.9', 'Mexico '],
#    ['767', '2/15/1999', '79091', '105', 'Mexico '],
#    ['2331', '2/15/1999', '79091', '535.5', 'Mexico '],
#    ['513', '2/15/1999', '79091', '451.4', 'Mexico '],
#    ['754', '2/15/1999', '79091', '244.1', 'Mexico '],
#    ['768', '2/15/1999', '79091', '105', 'Mexico '],
#    ['753', '2/15/1999', '79091', '244.1', 'Mexico '],
#    ['2050', '2/15/1999', '79091', '498.7', 'Mexico '],
#    ['992', '3/15/1999', '79091', '278.2', 'Mexico '],
#    ['769', '2/15/1999', '75481', '257.2', 'Mexico '],
#    ['770', '2/15/1999', '75481', '257.2', 'Mexico '],
#    ['725', '1/15/1999', '22401', '115.5', 'Mexico '],
#    ['769', '2/15/1999', '92001', '257.2', 'Mexico '],
#    ['396', '2/15/1999', '92001', '857.1', 'Mexico '],
#    ['770', '2/15/1999', '92001', '257.2', 'Mexico '],
#    ['901', '2/15/1999', '92001', '409.4', 'Mexico '],
#    ['443', '2/15/1999', '92001', '790.9', 'Mexico '],
#    ['1168', '6/3/2002', '92001', '377.9', 'Mexico '],
#    ['754', '3/15/1999', '92001', '241.4', 'Mexico '],
#    ['726', '1/15/1999', '22501', '115.5', 'Mexico '],
#    ['758', '1/15/1999', '22501', '84', 'Mexico '],
#    ['491', '4/12/2003', '22501', '890.7', 'Mexico '],
#    ['767', '1/15/1999', '22501', '105', 'Mexico '],
#    ['2388', '2/15/1999', '22501', '309.7', 'Mexico '],
#    ['769', '2/15/1999', '92491', '251.9', 'Mexico '],
#    ['770', '2/15/1999', '92491', '251.9', 'Mexico '],
#    ['609', '1/15/1999', '22601', '778.8', 'Mexico '],
#    ['599', '1/15/1999', '23101', '753.6', 'Mexico '],
#    ['1188', '2/15/1999', '90991', '472.4', 'Mexico '],
#    ['940', '2/15/1999', '23201', '687.7', 'Mexico '],
#    ['2120', '2/15/1999', '23201', '524.7', 'Mexico '],
#    ['1969', '2/15/1999', '78592', '477.6', 'Mexico '],
#    ['713', '2/15/1999', '78591', '160.1', 'Mexico '],
#    ['2255', '2/15/1999', '78591', '57.7', 'Mexico '],
#    ['2188', '1/15/1999', '78591', '233.6', 'Mexico '],
#    ['826', '5/31/2002', '78591', '918.7', 'Mexico '],
#    ['2254', '2/15/1999', '78591', '57.7', 'Mexico '],
#    ['714', '2/15/1999', '78591', '160.1', 'Mexico '],
#    ['1968', '2/15/1999', '78592', '477.6', 'Mexico '],
#    ['1139', '6/3/2002', '78591', '682.5', 'Mexico '],
#    ['2374', '3/15/1999', '78591', '630', 'Mexico '],
#    ['725', '1/15/1999', '23301', '115.5', 'Mexico '],
#    ['728', '1/15/1999', '23301', '63', 'Mexico '],
#    ['2380', '5/31/2002', '23301', '293.9', 'Mexico '],
#    ['2352', '2/15/1999', '23301', '367.4', 'Mexico '],
#    ['725', '3/15/1999', '23301', '115.5', 'Mexico '],
#    ['604', '1/15/1999', '23401', '461.7', 'Mexico '],
#    ['2331', '2/15/1999', '23401', '535.5', 'Mexico '],
#    ['550', '2/15/1999', '23401', '404', 'Mexico '],
#    ['714', '3/15/1999', '23401', '160.1', 'Mexico '],
#    ['2081', '2/15/1999', '77801', '220.4', 'Mexico '],
#    ['2204', '2/15/1999', '95401', '173.2', 'Mexico '],
#    ['910', '5/31/2002', '95401', '430.4', 'Mexico '],
#    ['2053', '6/3/2002', '95401', '325.4', 'Mexico '],
#    ['559', '2/15/1999', '95401', '585.6', 'Mexico '],
#    ['2255', '2/15/1999', '95401', '57.7', 'Mexico '],
#    ['559', '5/31/2002', '95401', '624.5', 'Mexico '],
#    ['2081', '2/15/1999', '95401', '220.4', 'Mexico '],
#    ['901', '2/15/1999', '95401', '409.4', 'Mexico '],
#    ['2205', '2/15/1999', '95401', '173.2', 'Mexico '],
#    ['1168', '2/15/1999', '95401', '367.4', 'Mexico '],
#    ['2254', '2/15/1999', '95401', '57.7', 'Mexico '],
#    ['2352', '3/15/1999', '95401', '367.4', 'Mexico '],
#    ['2255', '1/15/1999', '23601', '57.7', 'Mexico '],
#    ['981', '1/15/1999', '23601', '167.9', 'Mexico '],
#    ['597', '3/15/1999', '23601', '892.2', 'Mexico '],
#    ['2211', '2/15/1999', '94301', '107.6', 'Mexico '],
#    ['491', '4/11/2003', '94301', '890.7', 'Mexico '],
#    ['1144', '6/6/2002', '94301', '414.7', 'Mexico '],
#    ['2210', '2/15/1999', '94301', '107.6', 'Mexico '],
#    ['645', '1/15/1999', '24001', '746.5', 'Mexico '],
#    ['606', '2/15/1999', '24001', '314.7', 'Mexico '],
#    ['2235', '2/15/1999', '87601', '65.6', 'Mexico '],
#    ['964', '5/31/2002', '87602', '656.1', 'Mexico '],
#    ['979', '2/15/1999', '87601', '393.7', 'Mexico '],
#    ['2235', '1/15/1999', '87601', '65.6', 'Mexico '],
#    ['1436', '1/15/1999', '87601', '312.3', 'Mexico '],
#    ['396', '1/15/1999', '87601', '857.1', 'Mexico '],
#    ['2234', '2/15/1999', '87601', '65.6', 'Mexico '],
#    ['2388', '2/15/1999', '87601', '309.7', 'Mexico '],
#    ['992', '3/15/1999', '87601', '288.7', 'Mexico '],
#    ['2380', '3/15/1999', '87601', '309.7', 'Mexico '],
#    ['2255', '2/15/1999', '80301', '57.7', 'Mexico '],
#    ['2254', '2/15/1999', '80301', '57.7', 'Mexico '],
#    ['2277', '2/15/1999', '75501', '251.9', 'Mexico '],
#    ['1047', '4/10/2003', '75501', '209.9', 'Mexico '],
#    ['989', '5/31/2002', '75501', '419.9', 'Mexico '],
#    ['1935', '6/3/2002', '75501', '136.4', 'Mexico '],
#    ['513', '2/15/1999', '75501', '451.4', 'Mexico '],
#    ['609', '2/15/1999', '75501', '778.8', 'Mexico '],
#    ['725', '2/15/1999', '75501', '115.5', 'Mexico '],
#    ['1065', '2/15/1999', '75501', '296.6', 'Mexico '],
#    ['433', '1/15/1999', '75502', '1608.6', 'Mexico '],
#    ['726', '1/15/1999', '75501', '115.5', 'Mexico '],
#    ['726', '2/15/1999', '75501', '115.5', 'Mexico '],
#    ['767', '2/15/1999', '75501', '105', 'Mexico '],
#    ['1066', '2/15/1999', '75501', '296.6', 'Mexico '],
#    ['559', '2/15/1999', '75501', '585.6', 'Mexico '],
#    ['768', '2/15/1999', '75501', '105', 'Mexico '],
#    ['573', '2/15/1999', '75501', '280.6', 'Mexico '],
#    ['1934', '6/3/2002', '75501', '136.4', 'Mexico '],
#    ['475', '6/3/2002', '75501', '1007.2', 'Mexico '],
#    ['2373', '3/15/1999', '75501', '551.2', 'Mexico '],
#    ['989', '6/7/2002', '75501', '419.9', 'Mexico '],
#    ['2277', '2/15/1999', '78891', '251.9', 'Mexico '],
#    ['1173', '3/15/1999', '24201', '525', 'Mexico '],
#    ['2373', '2/15/1999', '92071', '551.2', 'Mexico '],
#    ['396', '2/15/1999', '92072', '1714.1', 'Mexico '],
#    ['2388', '1/15/1999', '92071', '309.7', 'Mexico '],
#    ['1085', '5/31/2002', '92071', '84', 'Mexico '],
#    ['1201', '5/31/2002', '92071', '577.5', 'Mexico '],
#    ['1927', '5/31/2002', '92071', '99.7', 'Mexico '],
#    ['1086', '5/31/2002', '92071', '84', 'Mexico '],
#    ['852', '2/15/1999', '92071', '761.2', 'Mexico '],
#    ['94', '2/15/1999', '92071', '866.2', 'Mexico '],
#    ['604', '2/15/1999', '92071', '461.7', 'Mexico '],
#    ['2012', '3/15/1999', '92071', '377.9', 'Mexico '],
#    ['2047', '3/15/1999', '92071', '377.9', 'Mexico '],
#    ['2070', '3/15/1999', '92071', '519.7', 'Mexico '],
#    ['729', '3/15/1999', '92071', '301.8', 'Mexico '],
#    ['396', '2/15/1999', '78101', '857.1', 'Mexico '],
#    ['2234', '3/15/1999', '24501', '65.6', 'Mexico '],
#    ['433', '2/15/1999', '94791', '804.3', 'Mexico '],
#    ['966', '5/31/2002', '94791', '472.4', 'Mexico '],
#    ['989', '2/15/1999', '94791', '467.2', 'Mexico '],
#    ['2192', '2/15/1999', '94791', '202.1', 'Mexico '],
#    ['725', '1/15/1999', '24601', '115.5', 'Mexico '],
#    ['767', '1/15/1999', '24701', '105', 'Mexico '],
#    ['757', '3/15/1999', '24701', '84', 'Mexico '],
#    ['551', '4/11/2003', '24701', '922.2', 'Mexico '],
#    ['573', '2/15/1999', '79301', '280.6', 'Mexico '],
#    ['2251', '4/11/2003', '79301', '126', 'Mexico '],
#    ['1081', '2/15/1999', '24791', '225.7', 'Mexico '],
#    ['604', '2/15/1999', '88201', '461.7', 'Mexico '],
#    ['2081', '5/31/2002', '88201', '225.7', 'Mexico '],
#    ['786', '5/31/2002', '88201', '68.2', 'Mexico '],
#    ['2054', '5/31/2002', '88201', '546', 'Mexico '],
#    ['1173', '2/15/1999', '88201', '525', 'Mexico '],
#    ['609', '2/15/1999', '88201', '778.8', 'Mexico '],
#    ['676', '2/15/1999', '88201', '801.9', 'Mexico '],
#    ['1110', '3/15/1999', '88201', '209.9', 'Mexico '],
#    ['2253', '4/10/2003', '78901', '136.4', 'Mexico '],
#    ['2252', '4/10/2003', '78901', '136.4', 'Mexico '],
#    ['2359', '6/5/2002', '78901', '430.4', 'Mexico '],
#    ['2252', '4/10/2003', '79101', '136.4', 'Mexico '],
#    ['2359', '5/31/2002', '79101', '430.4', 'Mexico '],
#    ['1227', '6/4/2002', '25001', '314.9', 'Mexico '],
#    ['1974', '4/10/2003', '88101', '57.7', 'Mexico '],
#    ['1980', '4/10/2003', '88101', '167.9', 'Mexico '],
#    ['1109', '4/11/2003', '25191', '209.9', 'Mexico '],
#    ['1110', '4/11/2003', '25191', '209.9', 'Mexico '],
#    ['550', '4/10/2003', '25191', '433.4', 'Mexico '],
#    ['604', '3/15/1999', '25192', '923.5', 'Mexico '],
#    ['2204', '3/15/1999', '25251', '173.2', 'Mexico '],
#    ['676', '4/10/2003', '87701', '856.3', 'Mexico '],
#    ['1005', '4/11/2003', '25301', '110.2', 'Mexico '],
#    ['1000', '4/10/2003', '25302', '178.4', 'Mexico '],
#    ['1203', '2/15/1999', '25301', '314.9', 'Mexico '],
#    ['895', '4/10/2003', '85801', '577.5', 'Mexico '],
#    ['559', '6/4/2002', '85801', '624.5', 'Mexico '],
#    ['1173', '2/15/1999', '85801', '525', 'Mexico '],
#    ['1174', '6/3/2002', '85801', '577.5', 'Mexico '],
#    ['1110', '4/11/2003', '26401', '209.9', 'Mexico '],
#    ['1109', '4/11/2003', '26401', '209.9', 'Mexico '],
#    ['2407', '4/13/2003', '26401', '81.3', 'Mexico '],
#    ['443', '4/11/2003', '77601', '851.3', 'Mexico '],
#    ['2254', '2/15/1999', '77601', '57.7', 'Mexico '],
#    ['645', '1/15/1999', '77601', '746.5', 'Mexico '],
#    ['1005', '1/15/1999', '77601', '107.6', 'Mexico '],
#    ['758', '1/15/1999', '77601', '84', 'Mexico '],
#    ['1106', '2/15/1999', '77601', '246.7', 'Mexico '],
#    ['1132', '2/15/1999', '77601', '630', 'Mexico '],
#    ['1105', '2/15/1999', '77601', '246.7', 'Mexico '],
#    ['2255', '2/15/1999', '77601', '57.7', 'Mexico '],
#    ['1911', '3/15/1999', '77601', '244.1', 'Mexico '],
#    ['1157', '1/15/1999', '26801', '377.9', 'Mexico '],
#    ['1046', '1/15/1999', '27101', '99.7', 'Mexico '],
#    ['952', '5/31/2002', '27101', '262.4', 'Mexico '],
#    ['964', '5/31/2002', '75401', '330.7', 'Mexico '],
#    ['838', '2/15/1999', '75401', '934.5', 'Mexico '],
#    ['964', '1/15/1999', '27291', '346.4', 'Mexico '],
#    ['2282', '1/15/1999', '27291', '304.4', 'Mexico '],
#    ['728', '1/15/1999', '27291', '63', 'Mexico '],
#    ['852', '3/15/1999', '27291', '745.5', 'Mexico '],
#    ['910', '4/12/2003', '27291', '430.4', 'Mexico '],
#    ['976', '4/12/2003', '27291', '325.4', 'Mexico '],
#    ['2074', '2/15/1999', '27291', '328.1', 'Mexico '],
#    ['1148', '6/3/2002', '27291', '314.9', 'Mexico '],
#    ['609', '2/15/1999', '27291', '778.8', 'Mexico '],
#    ['676', '2/15/1999', '27291', '801.9', 'Mexico '],
#    ['1489', '2/15/1999', '27291', '262.4', 'Mexico '],
#    ['604', '2/15/1999', '27291', '461.7', 'Mexico '],
#    ['1215', '6/3/2002', '80291', '356.9', 'Mexico '],
#    ['1131', '2/15/1999', '80291', '419.9', 'Mexico '],
#    ['728', '1/15/1999', '27301', '63', 'Mexico '],
#    ['681', '1/15/1999', '27301', '629.7', 'Mexico '],
#    ['1956', '1/15/1999', '27302', '307.6', 'Mexico '],
#    ['2284', '1/15/1999', '27301', '293.9', 'Mexico '],
#    ['768', '1/15/1999', '27301', '105', 'Mexico '],
#    ['716', '4/12/2003', '27301', '152.2', 'Mexico '],
#    ['785', '4/12/2003', '27301', '57.7', 'Mexico '],
#    ['715', '4/12/2003', '27301', '152.2', 'Mexico '],
#    ['915', '4/12/2003', '27301', '556.5', 'Mexico '],
#    ['786', '4/12/2003', '27301', '57.7', 'Mexico '],
#    ['981', '4/12/2003', '27301', '157.4', 'Mexico '],
#    ['573', '1/15/1999', '27301', '280.6', 'Mexico '],
#    ['727', '1/15/1999', '27301', '63', 'Mexico '],
#    ['1948', '3/15/1999', '27301', '296.6', 'Mexico '],
#    ['606', '3/15/1999', '27302', '629.5', 'Mexico '],
#    ['2380', '4/11/2003', '27391', '293.9', 'Mexico '],
#    ['758', '1/15/1999', '27391', '84', 'Mexico '],
#    ['1957', '1/15/1999', '27391', '153.8', 'Mexico '],
#    ['2388', '4/10/2003', '27391', '309.7', 'Mexico '],
#    ['493', '4/10/2003', '27601', '969.7', 'Mexico '],
#    ['475', '3/15/1999', '27601', '970.2', 'Mexico '],
#    ['2210', '3/15/1999', '27701', '107.6', 'Mexico '],
#    ['1080', '2/15/1999', '27701', '262.4', 'Mexico '],
#    ['1079', '2/15/1999', '27701', '262.4', 'Mexico '],
#    ['1169', '2/15/1999', '27701', '419.9', 'Mexico '],
#    ['574', '6/4/2002', '85201', '869.1', 'Mexico '],
#    ['962', '2/15/1999', '85201', '525', 'Mexico '],
#    ['2277', '2/15/1999', '85201', '251.9', 'Mexico '],
#    ['1927', '5/31/2002', '85201', '99.7', 'Mexico '],
#    ['2388', '2/15/1999', '85201', '309.7', 'Mexico '],
#    ['2070', '2/15/1999', '85202', '1039.4', 'Mexico '],
#    ['761', '4/12/2003', '28101', '173.2', 'Mexico '],
#    ['762', '4/12/2003', '28101', '173.2', 'Mexico '],
#    ['2282', '2/15/1999', '79181', '304.4', 'Mexico '],
#    ['2282', '2/15/1999', '90091', '304.4', 'Mexico '],
#    ['826', '6/8/2002', '90091', '918.7', 'Mexico '],
#    ['966', '5/31/2002', '28401', '472.4', 'Mexico '],
#    ['728', '1/15/1999', '28401', '63', 'Mexico '],
#    ['2284', '2/15/1999', '93401', '293.9', 'Mexico '],
#    ['1518', '2/15/1999', '93401', '141.7', 'Mexico '],
#    ['726', '5/31/2002', '93401', '120.7', 'Mexico '],
#    ['767', '2/15/1999', '93401', '105', 'Mexico '],
#    ['768', '2/15/1999', '93401', '105', 'Mexico '],
#    ['797', '2/15/1999', '93401', '301.8', 'Mexico '],
#    ['1517', '2/15/1999', '93401', '141.7', 'Mexico '],
#    ['1346', '1/15/1999', '28601', '304.4', 'Mexico '],
#    ['932', '3/15/1999', '28601', '430.4', 'Mexico '],
#    ['1345', '1/15/1999', '28601', '304.4', 'Mexico '],
#    ['2211', '2/15/1999', '28601', '107.6', 'Mexico '],
#    ['671', '4/10/2003', '28601', '944.7', 'Mexico '],
#    ['2210', '2/15/1999', '28601', '107.6', 'Mexico '],
#    ['910', '5/31/2002', '29201', '430.4', 'Mexico '],
#    ['2211', '2/15/1999', '29201', '107.6', 'Mexico '],
#    ['758', '1/15/1999', '29401', '84', 'Mexico '],
#    ['1948', '3/15/1999', '29401', '296.6', 'Mexico '],
#    ['1949', '3/15/1999', '29401', '296.6', 'Mexico '],
#    ['767', '2/15/1999', '77391', '102.3', 'Mexico '],
#    ['768', '2/15/1999', '77391', '102.3', 'Mexico '],
#    ['2282', '1/15/1999', '29801', '304.4', 'Mexico '],
#    ['559', '6/5/2002', '29801', '624.5', 'Mexico '],
#    ['1185', '2/15/1999', '79501', '419.9', 'Mexico '],
#    ['1053', '2/15/1999', '79501', '251.9', 'Mexico '],
#    ['1957', '2/15/1999', '80401', '153.8', 'Mexico '],
#    ['1956', '2/15/1999', '80401', '153.8', 'Mexico '],
#    ['2254', '1/15/1999', '40001', '57.7', 'Mexico '],
#    ['2192', '4/11/2003', '40001', '209.9', 'Mexico '],
#    ['2255', '1/15/1999', '40001', '57.7', 'Mexico '],
#    ['2046', '6/3/2002', '40001', '433.1', 'Mexico '],
#    ['1169', '1/15/1999', '40091', '435.7', 'Mexico '],
#    ['1430', '1/15/1999', '40091', '283.4', 'Mexico '],
#    ['2380', '5/31/2002', '40091', '293.9', 'Mexico '],
#    ['2064', '4/10/2003', '40091', '496.1', 'Mexico '],
#    ['2235', '2/15/1999', '92391', '65.6', 'Mexico '],
#    ['2234', '2/15/1999', '92391', '65.6', 'Mexico '],
#    ['757', '1/15/1999', '40101', '84', 'Mexico '],
#    ['758', '1/15/1999', '40101', '84', 'Mexico '],
#    ['1116', '1/15/1999', '40201', '251.9', 'Mexico '],
#    ['433', '4/11/2003', '40201', '880.2', 'Mexico '],
#    ['120', '2/15/1999', '40201', '829.5', 'Mexico '],
#    ['753', '3/15/1999', '40201', '244.1', 'Mexico '],
#    ['400', '2/15/1999', '92501', '683.8', 'Mexico '],
#    ['976', '5/31/2002', '92501', '314.9', 'Mexico '],
#    ['396', '6/7/2002', '92501', '892.2', 'Mexico '],
#    ['635', '4/9/2003', '41001', '881.7', 'Mexico '],
#    ['2082', '4/10/2003', '41001', '335.9', 'Mexico '],
#    ['964', '4/12/2003', '41001', '320.2', 'Mexico '],
#    ['609', '2/15/1999', '41001', '778.8', 'Mexico '],
#    ['676', '2/15/1999', '41001', '801.9', 'Mexico '],
#    ['2331', '2/15/1999', '41001', '535.5', 'Mexico '],
#    ['2359', '4/10/2003', '41001', '430.4', 'Mexico '],
#    ['475', '2/15/1999', '41001', '970.2', 'Mexico '],
#    ['491', '2/15/1999', '41291', '815.3', 'Mexico '],
#    ['681', '2/15/1999', '77901', '629.7', 'Mexico '],
#    ['2255', '6/7/2002', '77901', '60.3', 'Mexico '],
#    ['2254', '6/7/2002', '77901', '60.3', 'Mexico '],
#    ['2022', '5/31/2002', '42101', '230.9', 'Mexico '],
#    ['2054', '5/31/2002', '42101', '546', 'Mexico '],
#    ['2284', '1/15/1999', '42101', '293.9', 'Mexico '],
#    ['826', '5/31/2002', '42101', '945', 'Mexico '],
#    ['725', '2/15/1999', '90801', '115.5', 'Mexico '],
#    ['2340', '2/15/1999', '90801', '461.9', 'Mexico '],
#    ['726', '2/15/1999', '90801', '115.5', 'Mexico '],
#    ['981', '5/31/2002', '42301', '157.4', 'Mexico '],
#    ['727', '2/15/1999', '93201', '68.2', 'Mexico '],
#    ['728', '2/15/1999', '93201', '68.2', 'Mexico '],
#    ['837', '2/15/1999', '93201', '813.7', 'Mexico '],
#    ['768', '1/15/1999', '42391', '105', 'Mexico '],
#    ['1110', '1/15/1999', '42401', '209.9', 'Mexico '],
#    ['797', '3/15/1999', '42401', '301.8', 'Mexico '],
#    ['1116', '2/15/1999', '93691', '251.9', 'Mexico '],
#    ['2359', '5/31/2002', '93692', '860.9', 'Mexico '],
#    ['1112', '2/15/1999', '93691', '116.5', 'Mexico '],
#    ['1111', '2/15/1999', '93691', '116.5', 'Mexico '],
#    ['754', '1/15/1999', '42591', '244.1', 'Mexico '],
#    ['2331', '1/15/1999', '42591', '535.5', 'Mexico '],
#    ['2056', '2/15/1999', '42591', '325.4', 'Mexico '],
#    ['964', '4/10/2003', '42691', '330.7', 'Mexico '],
#    ['757', '2/15/1999', '42691', '84', 'Mexico '],
#    ['2057', '1/15/1999', '42701', '472.4', 'Mexico '],
#    ['1965', '4/10/2003', '42701', '89.2', 'Mexico '],
#    ['740', '2/15/1999', '42701', '170.6', 'Mexico '],
#    ['1964', '4/10/2003', '42701', '89.2', 'Mexico '],
#    ['1229', '2/15/1999', '42701', '236.2', 'Mexico '],
#    ['2064', '5/31/2002', '42801', '496.1', 'Mexico '],
#    ['726', '1/15/1999', '42801', '115.5', 'Mexico '],
#    ['1911', '2/15/1999', '42801', '244.1', 'Mexico '],
#    ['1085', '6/3/2002', '42801', '84', 'Mexico '],
#    ['1086', '6/3/2002', '42801', '84', 'Mexico '],
#    ['990', '3/15/1999', '42801', '503.9', 'Mexico '],
#    ['1960', '2/15/1999', '75601', '97.1', 'Mexico '],
#    ['573', '1/15/1999', '75601', '280.6', 'Mexico '],
#    ['1961', '2/15/1999', '75601', '97.1', 'Mexico '],
#    ['645', '2/15/1999', '75601', '746.5', 'Mexico '],
#    ['1122', '2/15/1999', '75601', '157.4', 'Mexico '],
#    ['1132', '2/15/1999', '75601', '630', 'Mexico '],
#    ['609', '2/15/1999', '75602', '1557.7', 'Mexico '],
#    ['609', '6/4/2002', '43091', '829.2', 'Mexico '],
#    ['2012', '5/31/2002', '43171', '388.4', 'Mexico '],
#    ['989', '2/15/1999', '43171', '467.2', 'Mexico '],
#    ['2255', '2/15/1999', '79691', '57.7', 'Mexico '],
#    ['1066', '1/15/1999', '79691', '296.6', 'Mexico '],
#    ['2255', '5/31/2002', '79691', '60.3', 'Mexico '],
#    ['1116', '2/15/1999', '79691', '251.9', 'Mexico '],
#    ['2254', '2/15/1999', '79691', '57.7', 'Mexico '],
#    ['2388', '5/31/2002', '79691', '309.7', 'Mexico '],
#    ['2056', '3/15/1999', '79691', '325.4', 'Mexico '],
#    ['2045', '5/31/2002', '43191', '419.9', 'Mexico '],
#    ['597', '2/15/1999', '43191', '892.2', 'Mexico '],
#    ['901', '3/15/1999', '43191', '409.4', 'Mexico '],
#    ['740', '5/31/2002', '43201', '173.2', 'Mexico '],
#    ['1201', '4/11/2003', '43201', '577.5', 'Mexico '],
#    ['642', '4/11/2003', '43201', '903.8', 'Mexico '],
#    ['819', '4/11/2003', '43201', '997.5', 'Mexico '],
#    ['2379', '1/15/1999', '87201', '209.9', 'Mexico '],
#    ['1975', '3/15/1999', '87201', '52.5', 'Mexico '],
#    ['396', '1/15/1999', '43261', '857.1', 'Mexico '],
#    ['1517', '1/15/1999', '43261', '141.7', 'Mexico '],
#    ['1182', '3/15/1999', '43261', '157.4', 'Mexico '],
#    ['786', '4/11/2003', '43261', '57.7', 'Mexico '],
#    ['1894', '1/15/1999', '43261', '682.2', 'Mexico '],
#    ['634', '4/11/2003', '43261', '897.8', 'Mexico '],
#    ['785', '4/11/2003', '43261', '57.7', 'Mexico '],
#    ['575', '4/11/2003', '43261', '929.2', 'Mexico '],
#    ['676', '2/15/1999', '43261', '801.9', 'Mexico '],
#    ['2331', '2/15/1999', '43261', '535.5', 'Mexico '],
#    ['2222', '3/15/1999', '43261', '246.7', 'Mexico '],
#    ['767', '3/15/1999', '43261', '105', 'Mexico '],
#    ['499', '3/15/1999', '43361', '846.3', 'Mexico '],
#    ['767', '1/15/1999', '43381', '105', 'Mexico '],
#    ['726', '1/15/1999', '43381', '115.5', 'Mexico '],
#    ['768', '2/15/1999', '43501', '105', 'Mexico '],
#    ['728', '1/15/1999', '90001', '63', 'Mexico '],
#    ['1956', '3/15/1999', '90001', '153.8', 'Mexico '],
#    ['1182', '1/15/1999', '78401', '157.4', 'Mexico '],
#    ['2045', '5/31/2002', '44201', '419.9', 'Mexico '],
#    ['2138', '5/31/2002', '44201', '398.9', 'Mexico '],
#    ['396', '1/15/1999', '44301', '857.1', 'Mexico '],
#    ['2121', '1/15/1999', '44301', '629.7', 'Mexico '],
#    ['930', '4/11/2003', '44301', '525', 'Mexico '],
#    ['1174', '5/31/2002', '44501', '577.5', 'Mexico '],
#    ['491', '2/15/1999', '44501', '815.3', 'Mexico '],
#    ['2045', '1/15/1999', '44701', '409.4', 'Mexico '],
#    ['2047', '2/15/1999', '44701', '377.9', 'Mexico '],
#    ['901', '3/15/1999', '44701', '409.4', 'Mexico '],
#    ['550', '2/15/1999', '44841', '404', 'Mexico '],
#    ['550', '3/15/1999', '44841', '404', 'Mexico '],
#    ['910', '3/15/1999', '44841', '414.7', 'Mexico '],
#    ['669', '4/10/2003', '45131', '1364.7', 'Mexico '],
#    ['609', '3/15/1999', '45301', '778.8', 'Mexico '],
#    ['2252', '5/31/2002', '75301', '136.4', 'Mexico '],
#    ['2253', '5/31/2002', '75301', '136.4', 'Mexico '],
#    ['2373', '5/31/2002', '94801', '619.5', 'Mexico '],
#    ['606', '6/3/2002', '94801', '323.1', 'Mexico '],
#    ['2199', '1/15/1999', '46101', '178.4', 'Mexico '],
#    ['1990', '3/15/1999', '46101', '257.2', 'Mexico '],
#    ['2064', '2/15/1999', '46101', '472.4', 'Mexico '],
#    ['2331', '2/15/1999', '46101', '535.5', 'Mexico '],
#    ['2094', '3/15/1999', '46101', '433.1', 'Mexico '],
#    ['600', '5/31/2002', '78691', '713.7', 'Mexico '],
#    ['739', '1/15/1999', '46201', '170.6', 'Mexico '],
#    ['992', '1/15/1999', '46201', '278.2', 'Mexico '],
#    ['740', '1/15/1999', '46201', '170.6', 'Mexico '],
#    ['981', '5/31/2002', '77201', '157.4', 'Mexico '],
#    ['914', '2/15/1999', '77201', '603.7', 'Mexico '],
#    ['475', '2/15/1999', '77201', '970.2', 'Mexico '],
#    ['816', '5/31/2002', '47001', '330.7', 'Mexico '],
#    ['2380', '5/31/2002', '88401', '293.9', 'Mexico '],
#    ['604', '5/31/2002', '76401', '480.6', 'Mexico '],
#    ['768', '1/15/1999', '76401', '105', 'Mexico '],
#    ['491', '3/15/1999', '47201', '815.3', 'Mexico '],
#    ['725', '5/31/2002', '79391', '120.7', 'Mexico '],
#    ['767', '1/15/1999', '79391', '105', 'Mexico '],
#    ['571', '4/11/2003', '47291', '527.1', 'Mexico '],
#    ['2373', '3/15/1999', '47291', '551.2', 'Mexico '],
#    ['769', '1/15/1999', '47301', '257.2', 'Mexico '],
#    ['714', '1/15/1999', '47301', '160.1', 'Mexico '],
#    ['962', '3/15/1999', '47371', '525', 'Mexico '],
#    ['2371', '1/15/1999', '47371', '551.2', 'Mexico '],
#    ['728', '2/15/1999', '47371', '63', 'Mexico '],
#    ['964', '5/31/2002', '93101', '314.9', 'Mexico '],
#    ['2388', '3/15/1999', '48001', '309.7', 'Mexico '],
#    ['596', '1/15/1999', '48491', '746.5', 'Mexico '],
#    ['1185', '2/15/1999', '48491', '419.9', 'Mexico '],
#    ['631', '1/15/1999', '81001', '346.2', 'Mexico '],
#    ['2277', '2/15/1999', '48901', '251.9', 'Mexico '],
#    ['962', '1/15/1999', '49081', '525', 'Mexico '],
#    ['571', '4/12/2003', '49081', '527.1', 'Mexico '],
#    ['573', '2/15/1999', '49081', '280.6', 'Mexico '],
#    ['981', '5/31/2002', '49081', '157.4', 'Mexico '],
#    ['443', '2/15/1999', '49081', '790.9', 'Mexico '],
#    ['2254', '1/15/1999', '94501', '57.7', 'Mexico '],
#    ['2388', '1/15/1999', '93681', '309.7', 'Mexico '],
#    ['604', '1/15/1999', '83201', '461.7', 'Mexico '],
#    ['609', '1/15/1999', '78581', '778.8', 'Mexico '],
#    ['609', '1/15/1999', '79801', '778.8', 'Mexico '],
#    ['2016', '5/31/2002', '79801', '304.4', 'Mexico '],
#    ['1182', '2/15/1999', '49701', '157.4', 'Mexico '],
#    ['604', '2/15/1999', '49701', '461.7', 'Mexico '],
#    ['1082', '2/15/1999', '49701', '225.7', 'Mexico '],
#    ['2070', '3/15/1999', '49701', '519.7', 'Mexico '],
#    ['1131', '2/15/1999', '49801', '419.9', 'Mexico '],
#    ['645', '2/15/1999', '50081', '746.5', 'Mexico '],
#    ['2359', '6/5/2002', '86191', '430.4', 'Mexico '],
#    ['443', '3/15/1999', '86191', '790.9', 'Mexico '],
#    ['2351', '2/15/1999', '86191', '314.9', 'Mexico '],
#    ['2045', '6/5/2002', '91201', '419.9', 'Mexico '],
#    ['767', '1/15/1999', '50301', '105', 'Mexico '],
#    ['631', '2/15/1999', '50301', '346.2', 'Mexico '],
#    ['2352', '6/3/2002', '50301', '367.4', 'Mexico '],
#    ['443', '2/15/1999', '50301', '790.9', 'Mexico '],
#    ['2091', '3/15/1999', '50301', '152.2', 'Mexico '],
#    ['574', '6/5/2002', '76001', '869.1', 'Mexico '],
#    ['573', '2/15/1999', '76001', '280.6', 'Mexico '],
#    ['319', '3/15/1999', '76001', '1102.2', 'Mexico '],
#    ['2234', '1/15/1999', '50391', '65.6', 'Mexico '],
#    ['1975', '2/15/1999', '50391', '52.5', 'Mexico '],
#    ['2054', '6/5/2002', '90601', '546', 'Mexico '],
#    ['739', '1/15/1999', '50501', '170.6', 'Mexico '],
#    ['606', '2/15/1999', '50501', '314.7', 'Mexico '],
#    ['1329', '2/15/1999', '50501', '92.8', 'Mexico '],
#    ['2269', '4/10/2003', '50501', '293.9', 'Mexico '],
#    ['823', '6/6/2002', '95001', '624.7', 'Mexico '],
#    ['768', '6/8/2002', '95001', '105', 'Mexico '],
#    ['767', '6/8/2002', '95001', '105', 'Mexico '],
#    ['573', '2/15/1999', '50861', '280.6', 'Mexico '],
#    ['2282', '1/15/1999', '50881', '304.4', 'Mexico '],
#    ['726', '1/15/1999', '50882', '230.9', 'Mexico '],
#    ['1477', '2/15/1999', '50881', '317.5', 'Mexico '],
#    ['532', '2/15/1999', '50881', '556.5', 'Mexico '],
#    ['599', '2/15/1999', '50881', '753.6', 'Mexico '],
#    ['901', '2/15/1999', '50881', '409.4', 'Mexico '],
#    ['962', '2/15/1999', '50881', '525', 'Mexico '],
#    ['550', '2/15/1999', '50882', '808', 'Mexico '],
#    ['604', '6/7/2002', '82301', '480.6', 'Mexico '],
#    ['1005', '1/15/1999', '50891', '107.6', 'Mexico '],
#    ['631', '2/15/1999', '50891', '346.2', 'Mexico '],
#    ['837', '2/15/1999', '50891', '840', 'Mexico '],
#    ['2074', '2/15/1999', '50891', '328.1', 'Mexico '],
#    ['1112', '2/15/1999', '92281', '116.5', 'Mexico '],
#    ['1111', '2/15/1999', '92281', '116.5', 'Mexico '],
#    ['713', '2/15/1999', '51291', '160.1', 'Mexico '],
#    ['550', '2/15/1999', '52101', '404', 'Mexico '],
#    ['491', '2/15/1999', '84001', '815.3', 'Mexico '],
#    ['992', '2/15/1999', '84001', '278.2', 'Mexico '],
#    ['2074', '6/3/2002', '84001', '335.9', 'Mexico '],
#    ['2332', '6/7/2002', '84001', '367.4', 'Mexico '],
#    ['604', '2/15/1999', '79901', '461.7', 'Mexico '],
#    ['2083', '6/4/2002', '52201', '317.6', 'Mexico '],
#    ['2250', '6/3/2002', '52681', '126', 'Mexico '],
#    ['2251', '6/3/2002', '52681', '126', 'Mexico '],
#    ['786', '5/31/2002', '52691', '68.2', 'Mexico '],
#    ['2277', '6/4/2002', '52701', '309.7', 'Mexico '],
#    ['936', '2/15/1999', '52701', '498.7', 'Mexico '],
#    ['2205', '3/15/1999', '52701', '173.2', 'Mexico '],
#    ['2211', '3/15/1999', '52701', '107.6', 'Mexico '],
#    ['1948', '2/15/1999', '93661', '296.6', 'Mexico '],
#    ['1949', '2/15/1999', '93661', '296.6', 'Mexico '],
#    ['964', '4/10/2003', '53481', '314.9', 'Mexico '],
#    ['2277', '2/15/1999', '53491', '251.9', 'Mexico '],
#    ['443', '3/15/1999', '76301', '790.9', 'Mexico '],
#    ['76', '4/11/2003', '53701', '865.7', 'Mexico '],
#    ['475', '1/15/1999', '53791', '970.2', 'Mexico '],
#    ['1111', '1/15/1999', '53791', '116.5', 'Mexico '],
#    ['2064', '4/10/2003', '53791', '496.1', 'Mexico '],
#    ['1213', '6/3/2002', '53791', '556.5', 'Mexico '],
#    ['2241', '6/3/2002', '53791', '89.2', 'Mexico '],
#    ['2252', '6/3/2002', '53791', '136.4', 'Mexico '],
#    ['2240', '6/3/2002', '53791', '89.2', 'Mexico '],
#    ['1956', '2/15/1999', '54101', '153.8', 'Mexico '],
#    ['596', '1/15/1999', '54801', '746.5', 'Mexico '],
#    ['1949', '1/15/1999', '54802', '593.1', 'Mexico '],
#    ['1109', '6/3/2002', '55091', '209.9', 'Mexico '],
#    ['1110', '6/3/2002', '55091', '209.9', 'Mexico '],
#    ['609', '2/15/1999', '55091', '778.8', 'Mexico '],
#    ['638', '4/10/2003', '55101', '1008.8', 'Mexico '],
#    ['631', '2/15/1999', '55201', '346.2', 'Mexico '],
#    ['2254', '6/4/2002', '56191', '60.3', 'Mexico '],
#    ['2255', '6/4/2002', '56191', '60.3', 'Mexico '],
#    ['2364', '2/15/1999', '57001', '325.4', 'Mexico '],
#    ['2331', '2/15/1999', '57201', '535.5', 'Mexico '],
#    ['1131', '2/15/1999', '57201', '419.9', 'Mexico '],
#    ['1173', '2/15/1999', '57601', '525', 'Mexico '],
#    ['499', '2/15/1999', '57701', '846.3', 'Mexico '],
#    ['2234', '2/15/1999', '70001', '65.6', 'Mexico '],
#    ['2055', '4/10/2003', '70001', '569.6', 'Mexico '],
#    ['1201', '4/10/2003', '70001', '577.5', 'Mexico '],
#    ['2235', '2/15/1999', '70001', '65.6', 'Mexico '],
#    ['1430', '3/15/1999', '70201', '283.4', 'Mexico '],
#    ['433', '2/15/1999', '70501', '804.3', 'Mexico '],
#    ['1066', '4/10/2003', '70801', '304.4', 'Mexico '],
#    ['606', '1/15/1999', '70891', '314.7', 'Mexico '],
#    ['1517', '2/15/1999', '70891', '141.7', 'Mexico '],
#    ['2239', '4/11/2003', '70891', '126', 'Mexico '],
#    ['2284', '2/15/1999', '70891', '293.9', 'Mexico '],
#    ['1518', '2/15/1999', '70891', '141.7', 'Mexico '],
#    ['990', '2/15/1999', '71001', '472.4', 'Mexico '],
#    ['599', '2/15/1999', '71001', '753.6', 'Mexico '],
#    ['604', '1/15/1999', '71101', '461.7', 'Mexico '],
#    ['475', '2/15/1999', '71101', '970.2', 'Mexico '],
#    ['609', '2/15/1999', '71481', '778.8', 'Mexico '],
#    ['2331', '1/15/1999', '71501', '535.5', 'Mexico '],
#    ['739', '2/15/1999', '71601', '170.6', 'Mexico '],
#    ['740', '2/15/1999', '71601', '170.6', 'Mexico '],
#    ['573', '1/15/1999', '71831', '280.6', 'Mexico '],
#    ['1116', '4/11/2003', '71831', '262.4', 'Mexico '],
#    ['954', '5/31/2002', '71871', '682.5', 'Mexico '],
#    ['604', '2/15/1999', '71871', '461.7', 'Mexico '],
#    ['2081', '3/15/1999', '71991', '220.4', 'Mexico '],
#    ['758', '1/15/1999', '72001', '84', 'Mexico '],
#    ['1168', '5/31/2002', '72092', '734.9', 'Mexico '],
#    ['499', '2/15/1999', '72101', '846.3', 'Mexico '],
#    ['658', '2/15/1999', '72191', '902.7', 'Mexico '],
#    ['631', '2/15/1999', '72191', '346.2', 'Mexico '],
#    ['768', '2/15/1999', '72301', '105', 'Mexico '],
#    ['2054', '6/3/2002', '72301', '546', 'Mexico '],
#    ['491', '2/15/1999', '72301', '815.3', 'Mexico '],
#    ['2045', '3/15/1999', '72301', '409.4', 'Mexico '],
#    ['1082', '5/31/2002', '72401', '230.9', 'Mexico '],
#    ['443', '2/15/1999', '72801', '790.9', 'Mexico '],
#    ['768', '1/15/1999', '73261', '105', 'Mexico '],
#    ['502', '4/11/2003', '73501', '1105.9', 'Mexico '],
#    ['767', '5/31/2002', '73591', '105', 'Mexico '],
#    ['2235', '2/15/1999', '73801', '65.6', 'Mexico '],
#    ['728', '2/15/1999', '74101', '63', 'Mexico '],
#    ['1081', '2/15/1999', '74501', '225.7', 'Mexico '],
#    ['796', '5/31/2002', '74581', '278.2', 'Mexico '],
#    ['1225', '2/15/1999', '74581', '236.2', 'Mexico '],
#    ['1065', '1/15/1999', '75091', '296.6', 'Mexico '],
#    ['120', '2/15/1999', '75091', '829.5', 'Mexico '],
#    ['1215', '2/15/1999', '75091', '356.9', 'Mexico '],
#    ['1173', '3/15/1999', '75731', '525', 'Mexico '],
#    ['396', '3/15/1999', '78601', '857.1', 'Mexico '],
#    ['663', '2/15/1999', '79581', '765.5', 'Mexico '],
#    ['596', '2/15/1999', '79581', '746.5', 'Mexico '],
#    ['2050', '3/15/1999', '79581', '498.7', 'Mexico '],
#    ['574', '6/8/2002', '80001', '869.1', 'Mexico '],
#    ['491', '2/15/1999', '82101', '815.3', 'Mexico '],
#    ['1065', '3/15/1999', '82401', '296.6', 'Mexico '],
#    ['2204', '3/15/1999', '83001', '173.2', 'Mexico '],
#    ['2371', '3/15/1999', '85101', '551.2', 'Mexico '],
#    ['606', '2/15/1999', '92081', '314.7', 'Mexico '],
#    ['740', '2/15/1999', '94401', '170.6', 'Mexico '],
#    ['739', '2/15/1999', '94401', '170.6', 'Mexico '],
#    ['2277', '2/15/1999', '94381', '251.9', 'Mexico '],
#    ['2234', '3/15/1999', '51291', '65.6', 'Mexico '],
#    ['2255', '3/15/1999', '50501', '57.7', 'Mexico '],
#    ['2373', '3/15/1999', '50891', '551.2', 'Mexico '],
#    ['2388', '3/15/1999', '72191', '309.7', 'Mexico '],
#    ['443', '3/15/1999', '52101', '790.9', 'Mexico '],
#    ['475', '3/15/1999', '72391', '970.2', 'Mexico '],
#    ['513', '3/15/1999', '75091', '451.4', 'Mexico '],
#    ['687', '3/15/1999', '50881', '446', 'Mexico '],
#    ['757', '3/15/1999', '55091', '84', 'Mexico '],
#    ['769', '3/15/1999', '73281', '257.2', 'Mexico '],
#    ['833', '3/15/1999', '73281', '792.7', 'Mexico '],
#    ['964', '3/15/1999', '51301', '346.4', 'Mexico '],
#    ['992', '3/15/1999', '72191', '278.2', 'Mexico '],
#    ['1005', '3/15/1999', '72401', '107.6', 'Mexico '],
#    ['1168', '3/15/1999', '72101', '367.4', 'Mexico '],
#    ['714', '1/15/1999', '77081', '160.1', 'Mexico '],
#    ['757', '1/15/1999', '94101', '84', 'Mexico '],
#    ['758', '1/15/1999', '77901', '84', 'Mexico '],
#    ['767', '1/15/1999', '76401', '105', 'Mexico '],
#    ['768', '1/15/1999', '85001', '105', 'Mexico '],
#    ['771', '1/15/1999', '93301', '165.3', 'Mexico '],
#    ['1065', '1/15/1999', '79691', '296.6', 'Mexico '],
#    ['1166', '1/15/1999', '88301', '535.5', 'Mexico '],
#    ['1517', '1/15/1999', '94291', '141.7', 'Mexico '],
#    ['1948', '1/15/1999', '90001', '296.6', 'Mexico '],
#    ['1949', '1/15/1999', '90102', '593.1', 'Mexico '],
#    ['1974', '1/15/1999', '75801', '52.5', 'Mexico '],
#    ['2064', '1/15/1999', '79581', '488.2', 'Mexico '],
#    ['2210', '1/15/1999', '94001', '107.6', 'Mexico '],
#    ['2235', '1/15/1999', '77401', '65.6', 'Mexico '],
#    ['2235', '1/15/1999', '78001', '65.6', 'Mexico '],
#    ['2255', '1/15/1999', '94501', '57.7', 'Mexico '],
#    ['606', '1/15/1999', '78591', '314.7', 'Mexico '],
#    ['609', '1/15/1999', '79091', '778.8', 'Mexico '],
#    ['676', '1/15/1999', '92271', '801.9', 'Mexico '],
#    ['726', '1/15/1999', '75801', '115.5', 'Mexico '],
#    ['757', '1/15/1999', '90201', '84', 'Mexico '],
#    ['758', '1/15/1999', '75802', '167.9', 'Mexico '],
#    ['1005', '1/15/1999', '91501', '107.6', 'Mexico '],
#    ['1957', '1/15/1999', '90101', '153.8', 'Mexico '],
#    ['2032', '1/15/1999', '79091', '220.4', 'Mexico '],
#    ['2234', '1/15/1999', '87601', '65.6', 'Mexico '],
#    ['491', '1/15/1999', '90991', '815.3', 'Mexico '],
#    ['559', '1/15/1999', '79581', '585.6', 'Mexico '],
#    ['606', '1/15/1999', '85801', '312.1', 'Mexico '],
#    ['676', '1/15/1999', '79901', '801.9', 'Mexico '],
#    ['238', '5/31/2002', '82101', '367.2', 'Mexico '],
#    ['596', '5/31/2002', '95401', '776.7', 'Mexico '],
#    ['635', '5/31/2002', '76001', '860.7', 'Mexico '],
#    ['770', '5/31/2002', '77701', '251.9', 'Mexico '],
#    ['966', '5/31/2002', '78001', '472.4', 'Mexico '],
#    ['966', '5/31/2002', '86191', '472.4', 'Mexico '],
#    ['989', '5/31/2002', '80291', '419.9', 'Mexico '],
#    ['1909', '5/31/2002', '91601', '204.7', 'Mexico '],
#    ['2254', '5/31/2002', '79691', '60.3', 'Mexico '],
#    ['464', '5/31/2002', '92071', '866.2', 'Mexico '],
#    ['647', '5/31/2002', '92071', '900.6', 'Mexico '],
#    ['1981', '4/10/2003', '88101', '167.9', 'Mexico '],
#    ['2253', '4/10/2003', '79101', '136.4', 'Mexico '],
#    ['964', '4/10/2003', '86501', '330.7', 'Mexico '],
#    ['976', '4/10/2003', '79901', '325.4', 'Mexico '],
#    ['1047', '4/10/2003', '77601', '209.9', 'Mexico '],
#    ['1975', '4/10/2003', '88101', '57.7', 'Mexico '],
#    ['2064', '4/10/2003', '86191', '496.1', 'Mexico '],
#    ['725', '1/15/1999', '75501', '115.5', 'Mexico '],
#    ['725', '1/15/1999', '75801', '115.5', 'Mexico '],
#    ['728', '1/15/1999', '76001', '63', 'Mexico '],
#    ['757', '1/15/1999', '77601', '84', 'Mexico '],
#    ['757', '1/15/1999', '77901', '84', 'Mexico '],
#    ['758', '1/15/1999', '90201', '84', 'Mexico '],
#    ['768', '1/15/1999', '79391', '105', 'Mexico '],
#    ['768', '1/15/1999', '79581', '105', 'Mexico '],
#    ['768', '1/15/1999', '94101', '105', 'Mexico '],
#    ['833', '1/15/1999', '90801', '798', 'Mexico '],
#    ['1182', '1/15/1999', '77401', '157.4', 'Mexico '],
#    ['1435', '1/15/1999', '87601', '312.3', 'Mexico '],
#    ['1949', '1/15/1999', '90001', '296.6', 'Mexico '],
#    ['2083', '1/15/1999', '92291', '309.7', 'Mexico '],
#    ['2210', '1/15/1999', '92201', '107.6', 'Mexico '],
#    ['757', '3/15/1999', '75701', '84', 'Mexico '],
#    ['757', '3/15/1999', '78591', '84', 'Mexico '],
#    ['757', '3/15/1999', '85201', '84', 'Mexico '],
#    ['771', '3/15/1999', '92401', '165.3', 'Mexico '],
#    ['797', '3/15/1999', '77291', '301.8', 'Mexico '],
#    ['838', '3/15/1999', '84001', '934.5', 'Mexico '],
#    ['847', '3/15/1999', '90801', '551.2', 'Mexico '],
#    ['921', '3/15/1999', '95402', '1049.9', 'Mexico '],
#    ['936', '3/15/1999', '93401', '498.7', 'Mexico '],
#    ['936', '3/15/1999', '94101', '498.7', 'Mexico '],
#    ['962', '3/15/1999', '77601', '509.2', 'Mexico '],
#    ['992', '3/15/1999', '75701', '278.2', 'Mexico '],
#    ['1116', '3/15/1999', '75501', '251.9', 'Mexico '],
#    ['1330', '3/15/1999', '92291', '92.8', 'Mexico '],
#    ['1894', '3/15/1999', '75501', '682.2', 'Mexico '],
#    ['1930', '3/15/1999', '77401', '286.1', 'Mexico '],
#    ['1961', '3/15/1999', '75481', '97.1', 'Mexico '],
#    ['1974', '3/15/1999', '90091', '52.5', 'Mexico '],
#    ['1974', '3/15/1999', '92071', '52.5', 'Mexico '],
#    ['762', '4/11/2003', '94101', '173.2', 'Mexico '],
#    ['2250', '4/11/2003', '79301', '126', 'Mexico '],
#    ['976', '4/11/2003', '75701', '314.9', 'Mexico '],
#    ['498', '4/11/2003', '90701', '1469.7', 'Mexico '],
#    ['600', '4/11/2003', '79691', '747.3', 'Mexico '],
#    ['606', '4/11/2003', '75501', '337.8', 'Mexico '],
#    ['609', '4/11/2003', '75501', '850.2', 'Mexico '],
#    ['761', '4/11/2003', '94101', '173.2', 'Mexico '],
#    ['486', '4/11/2003', '78581', '980.2', 'Mexico '],
#    ['606', '4/11/2003', '85101', '337.8', 'Mexico '],
#    ['989', '4/11/2003', '94301', '419.9', 'Mexico '],
#    ['443', '4/12/2003', '76301', '851.3', 'Mexico '],
#    ['551', '4/12/2003', '92071', '922.2', 'Mexico '],
#    ['725', '4/12/2003', '85001', '110.2', 'Mexico '],
#    ['726', '4/12/2003', '85001', '110.2', 'Mexico '],
#    ['508', '4/12/2003', '77401', '969.7', 'Mexico '],
#    ['493', '4/14/2003', '85001', '969.7', 'Mexico '],
#    ['2032', '3/15/1999', '92071', '223.1', 'Mexico '],
#    ['2083', '3/15/1999', '88201', '309.7', 'Mexico '],
#    ['2094', '3/15/1999', '95401', '433.1', 'Mexico '],
#    ['2167', '3/15/1999', '77801', '577.2', 'Mexico '],
#    ['2211', '3/15/1999', '92001', '107.6', 'Mexico '],
#    ['2234', '3/15/1999', '75501', '65.6', 'Mexico '],
#    ['2235', '3/15/1999', '77401', '65.6', 'Mexico '],
#    ['2255', '3/15/1999', '77402', '115.4', 'Mexico '],
#    ['2255', '3/15/1999', '78002', '115.4', 'Mexico '],
#    ['2290', '3/15/1999', '77401', '787.5', 'Mexico '],
#    ['2331', '3/15/1999', '85201', '535.5', 'Mexico '],
#    ['2352', '3/15/1999', '90102', '734.9', 'Mexico '],
#    ['2373', '3/15/1999', '77801', '551.2', 'Mexico '],
#    ['2388', '3/15/1999', '75481', '309.7', 'Mexico '],
#    ['2388', '3/15/1999', '85101', '309.7', 'Mexico '],
#    ['36', '3/15/1999', '88301', '414.8', 'Mexico '],
#    ['93', '3/15/1999', '82101', '939.8', 'Mexico '],
#    ['400', '3/15/1999', '78801', '683.8', 'Mexico '],
#    ['475', '3/15/1999', '88201', '970.2', 'Mexico '],
#    ['604', '3/15/1999', '78101', '461.7', 'Mexico '],
#    ['609', '3/15/1999', '85001', '778.8', 'Mexico '],
#    ['681', '3/15/1999', '75601', '629.7', 'Mexico '],
#    ['727', '3/15/1999', '77291', '63', 'Mexico '],
#    ['729', '3/15/1999', '95401', '301.8', 'Mexico '],
#    ['768', '3/15/1999', '75701', '105', 'Mexico '],
#    ['796', '3/15/1999', '77601', '275.6', 'Mexico '],
# ...
#    ['768', '3/15/1999', 'T2X', '1', '104.9', 'Canada '],
#    ['989', '3/15/1999', 'V6A', '1', '451.4', 'Canada '],
#    ['1008', '3/15/1999', 'T5J', '1', '236.2', 'Canada '],
#    ['769', '1/15/1999', 'V5V', '1', '257.2', 'Canada '],
#    ['796', '1/15/1999', 'V5Z', '1', '275.6', 'Canada '],
#    ['797', '1/15/1999', 'V6M', '1', '301.8', 'Canada '],
#    ['962', '1/15/1999', 'T1Y', '1', '524.9', 'Canada '],
#    ['1003', '1/15/1999', 'T3G', '1', '86.6', 'Canada '],
#    ['1066', '1/15/1999', 'T2T', '1', '296.6', 'Canada '],
#    ['1079', '1/15/1999', 'V6B', '1', '262.4', 'Canada '],
#    ['2234', '1/15/1999', 'V6T', '1', '65.6', 'Canada '],
#    ['2235', '1/15/1999', 'V6G', '1', '65.6', 'Canada '],
#    ['2255', '1/15/1999', 'V7M', '1', '57.7', 'Canada '],
#    ['2388', '1/15/1999', 'R2P', '1', '309.7', 'Canada '],
#    ['604', '1/15/1999', 'T6S', '1', '461.7', 'Canada '],
#    ['631', '1/15/1999', 'T6T', '1', '346.2', 'Canada '],
#    ['725', '1/15/1999', 'T2X', '1', '115.4', 'Canada '],
#    ['769', '1/15/1999', 'V6H', '1', '257.2', 'Canada '],
#    ['1014', '1/15/1999', 'V6T', '1', '86.6', 'Canada '],
#    ['1014', '1/15/1999', 'R2G', '1', '86.6', 'Canada '],
#    ['1949', '1/15/1999', 'R2G', '1', '296.6', 'Canada '],
#    ['2234', '1/15/1999', 'V5W', '1', '65.6', 'Canada '],
#    ['2254', '1/15/1999', 'V6M', '1', '57.7', 'Canada '],
#    ['2255', '1/15/1999', 'V5Y', '1', '57.7', 'Canada '],
#    ['433', '1/15/1999', 'T6E', '1', '804.3', 'Canada '],
#    ['491', '1/15/1999', 'T6R', '1', '815.3', 'Canada '],
#    ['606', '1/15/1999', 'T6T', '1', '314.7', 'Canada '],
#    ['645', '1/15/1999', 'T6R', '1', '746.5', 'Canada '],
#    ['683', '1/15/1999', 'T5G', '1', '788', 'Canada '],
#    ['713', '1/15/1999', 'V6T', '1', '160.1', 'Canada '],
#    ['604', '5/31/2002', 'V5N', '1', '480.6', 'Canada '],
#    ['726', '5/31/2002', 'T2C', '1', '120.7', 'Canada '],
#    ['785', '5/31/2002', 'R2G', '2', '136.4', 'Canada '],
#    ['1006', '5/31/2002', 'V5Z', '1', '89.2', 'Canada '],
#    ['2045', '5/31/2002', 'T6K', '1', '419.9', 'Canada '],
#    ['2054', '5/31/2002', 'T6X', '1', '545.9', 'Canada '],
#    ['2071', '5/31/2002', 'V6G', '1', '346.4', 'Canada '],
#    ['475', '4/10/2003', 'V7Y', '1', '1037.4', 'Canada '],
#    ['508', '4/10/2003', 'V6G', '1', '969.7', 'Canada '],
#    ['617', '4/10/2003', 'V6H', '1', '844.7', 'Canada '],
#    ['726', '1/15/1999', 'T5V', '1', '115.4', 'Canada '],
#    ['767', '1/15/1999', 'T5Y', '1', '102.3', 'Canada '],
#    ['767', '1/15/1999', 'V6Z', '1', '104.9', 'Canada '],
#    ['768', '1/15/1999', 'T5K', '1', '104.9', 'Canada '],
#    ['770', '1/15/1999', 'V5V', '1', '257.2', 'Canada '],
#    ['797', '1/15/1999', 'T2J', '1', '301.8', 'Canada '],
#    ['992', '1/15/1999', 'V6T', '1', '288.7', 'Canada '],
#    ['1005', '1/15/1999', 'T2X', '1', '107.6', 'Canada '],
#    ['2056', '1/15/1999', 'T2X', '1', '325.4', 'Canada '],
#    ['2056', '6/3/2002', 'T6T', '1', '330.7', 'Canada '],
#    ['2064', '6/3/2002', 'T2X', '1', '496.1', 'Canada '],
#    ['676', '6/5/2002', 'T6E', '1', '837.4', 'Canada '],
#    ['2331', '2/15/1999', 'T2X', '1', '535.4', 'Canada '],
#    ['2407', '2/15/1999', 'T3G', '1', '73.4', 'Canada '],
#    ['94', '2/15/1999', 'T6V', '1', '866.2', 'Canada '],
#    ['120', '2/15/1999', 'T3J', '1', '829.5', 'Canada '],
#    ['443', '2/15/1999', 'T5Y', '1', '790.9', 'Canada '],
#    ['645', '2/15/1999', 'T6T', '1', '746.5', 'Canada '],
#    ['658', '2/15/1999', 'T5W', '1', '902.7', 'Canada '],
#    ['681', '2/15/1999', 'T6E', '1', '629.7', 'Canada '],
#    ['739', '2/15/1999', 'V5N', '1', '170.6', 'Canada '],
#    ['753', '2/15/1999', 'V7N', '1', '244.1', 'Canada '],
#    ['767', '2/15/1999', 'V6M', '1', '104.9', 'Canada '],
#    ['838', '2/15/1999', 'V6Z', '1', '934.4', 'Canada '],
#    ['1173', '2/15/1999', 'V6C', '1', '524.9', 'Canada '],
#    ['1182', '2/15/1999', 'R2L', '1', '157.4', 'Canada '],
#    ['1450', '2/15/1999', 'T6V', '1', '118', 'Canada '],
#    ['2388', '2/15/1999', 'T2C', '1', '309.7', 'Canada '],
#    ['396', '2/15/1999', 'V5V', '1', '857.1', 'Canada '],
#    ['599', '2/15/1999', 'T6J', '1', '753.6', 'Canada '],
#    ['609', '2/15/1999', 'T2J', '1', '778.8', 'Canada '],
#    ['725', '2/15/1999', 'V5Z', '1', '115.4', 'Canada '],
#    ['728', '2/15/1999', 'V5Z', '1', '62.9', 'Canada '],
#    ['740', '2/15/1999', 'V6A', '1', '170.6', 'Canada '],
#    ['1065', '2/15/1999', 'T1Y', '1', '296.6', 'Canada '],
#    ['1116', '2/15/1999', 'T6E', '1', '251.9', 'Canada '],
#    ['1185', '2/15/1999', 'T6K', '1', '419.9', 'Canada '],
#    ['1425', '2/15/1999', 'V5Z', '1', '286', 'Canada '],
#    ['1641', '2/15/1999', 'T6K', '1', '70.8', 'Canada '],
#    ['1949', '2/15/1999', 'V6M', '1', '293.9', 'Canada '],
#    ['1975', '2/15/1999', 'T6T', '1', '52.4', 'Canada '],
#    ['2210', '2/15/1999', 'V7Y', '1', '107.6', 'Canada '],
#    ['396', '2/15/1999', 'V7W', '1', '857.1', 'Canada '],
#    ['2094', '3/15/1999', 'V6E', '1', '433.1', 'Canada '],
#    ['2126', '3/15/1999', 'T3C', '1', '472.2', 'Canada '],
#    ['2205', '3/15/1999', 'V7Y', '1', '173.2', 'Canada '],
#    ['2210', '3/15/1999', 'V5Z', '1', '104.9', 'Canada '],
#    ['2234', '3/15/1999', 'V7W', '1', '65.6', 'Canada '],
#    ['2255', '3/15/1999', 'V7M', '1', '57.7', 'Canada '],
#    ['2282', '3/15/1999', 'T2S', '1', '304.4', 'Canada '],
#    ['2284', '3/15/1999', 'T6T', '1', '293.9', 'Canada '],
#    ['318', '3/15/1999', 'T3G', '1', '866', 'Canada '],
#    ['609', '3/15/1999', 'V6G', '1', '778.8', 'Canada '],
#    ['740', '3/15/1999', 'V5N', '1', '170.6', 'Canada '],
#    ['910', '3/15/1999', 'R2L', '1', '414.7', 'Canada '],
#    ['921', '3/15/1999', 'V5W', '1', '524.9', 'Canada '],
#    ['981', '3/15/1999', 'T6R', '1', '167.9', 'Canada '],
#    ['992', '3/15/1999', 'V6J', '1', '288.7', 'Canada '],
#    ['1003', '3/15/1999', 'T3G', '1', '86.6', 'Canada '],
#    ['1014', '3/15/1999', 'V5Z', '1', '86.6', 'Canada '],
#    ['1106', '3/15/1999', 'V6Z', '1', '246.7', 'Canada '],
#    ['1110', '3/15/1999', 'T2J', '1', '209.9', 'Canada '],
#    ['1182', '3/15/1999', 'V6R', '1', '157.4', 'Canada '],
#    ['1215', '3/15/1999', 'T3G', '1', '356.9', 'Canada '],
#    ['1346', '3/15/1999', 'T5G', '1', '304.4', 'Canada '],
#    ['1974', '3/15/1999', 'V5N', '1', '52.4', 'Canada '],
#    ['2045', '3/15/1999', 'T5H', '1', '409.4', 'Canada '],
#    ['2047', '3/15/1999', 'V6Z', '1', '377.9', 'Canada '],
#    ['2056', '3/15/1999', 'V6R', '1', '325.4', 'Canada '],
#    ['2070', '3/15/1999', 'T5Y', '1', '519.7', 'Canada '],
#    ['2083', '3/15/1999', 'V6L', '1', '309.7', 'Canada '],
#    ['2083', '3/15/1999', 'V7Y', '1', '309.7', 'Canada '],
#    ['2234', '3/15/1999', 'T6T', '1', '65.6', 'Canada '],
#    ['2277', '3/15/1999', 'V5W', '1', '251.9', 'Canada '],
#    ['574', '6/10/2002', 'R2G', '1', '869.1', 'Canada '],
#    ['1003', '6/11/2002', 'T3C', '1', '86.6', 'Canada '],
#    ['910', '6/11/2002', 'T5K', '1', '430.4', 'Canada '],
#    ['94', '6/11/2002', 'T5B', '1', '892', 'Canada '],
#    ['596', '6/11/2002', 'T6H', '1', '776.7', 'Canada '],
#    ['2388', '6/11/2002', 'V7Y', '1', '309.7', 'Canada '],
#    ['671', '6/11/2002', 'V5W', '1', '892.2', 'Canada '],
#    ['976', '6/11/2002', 'T2J', '1', '314.9', 'Canada '],
#    ['1230', '6/12/2002', 'V5T', '1', '524.9', 'Canada '],
#    ['921', '4/15/1999', 'V5Y', '1', '524.9', 'Canada '],
#    ['1065', '4/15/1999', 'T3C', '1', '296.6', 'Canada '],
#    ['1081', '4/15/1999', 'V6B', '1', '225.7', 'Canada '],
#    ['1157', '4/15/1999', 'T6E', '1', '377.9', 'Canada '],
#    ['1157', '4/15/1999', 'V6G', '1', '377.9', 'Canada '],
#    ['1182', '4/15/1999', 'T6T', '1', '157.4', 'Canada '],
#    ['1182', '4/15/1999', 'R2G', '1', '157.4', 'Canada '],
#    ['1987', '5/31/2002', 'T6S', '1', '162.7', 'Canada '],
#    ['2253', '5/31/2002', 'T6R', '2', '272.9', 'Canada '],
#    ['2352', '5/31/2002', 'T5S', '1', '367.4', 'Canada '],
#    ['683', '2/15/1999', 'T2Y', '1', '788', 'Canada '],
#    ['687', '2/15/1999', 'T6T', '1', '446', 'Canada '],
#    ['727', '2/15/1999', 'V5Z', '1', '62.9', 'Canada '],
#    ['739', '2/15/1999', 'V6A', '1', '170.6', 'Canada '],
#    ['739', '2/15/1999', 'V6T', '1', '170.6', 'Canada '],
#    ['757', '2/15/1999', 'T2A', '1', '83.9', 'Canada '],
#    ['758', '2/15/1999', 'T6E', '1', '83.9', 'Canada '],
#    ['964', '2/15/1999', 'T5V', '1', '346.4', 'Canada '],
#    ['990', '2/15/1999', 'T6E', '1', '503.9', 'Canada '],
#    ['1960', '2/15/1999', 'T5Y', '1', '97.1', 'Canada '],
#    ['2056', '2/15/1999', 'T2X', '1', '325.4', 'Canada '],
#    ['2211', '2/15/1999', 'V7Y', '1', '107.6', 'Canada '],
#    ['2279', '2/15/1999', 'V7M', '1', '165.3', 'Canada '],
#    ['2388', '2/15/1999', 'V7Y', '1', '309.7', 'Canada '],
#    ['491', '2/15/1999', 'T3R', '1', '815.3', 'Canada '],
#    ['550', '2/15/1999', 'V6T', '1', '404', 'Canada '],
#    ['663', '2/15/1999', 'V6T', '1', '765.5', 'Canada '],
#    ['726', '2/15/1999', 'V5N', '1', '115.4', 'Canada '],
#    ['726', '2/15/1999', 'V6M', '1', '115.4', 'Canada '],
#    ['1173', '2/15/1999', 'V6M', '1', '524.9', 'Canada '],
#    ['2373', '2/15/1999', 'T6S', '1', '551.2', 'Canada '],
#    ['330', '2/15/1999', 'T6V', '1', '577.2', 'Canada '],
#    ['499', '2/15/1999', 'V6Z', '1', '846.3', 'Canada '],
#    ['604', '2/15/1999', 'R2M', '1', '461.7', 'Canada '],
#    ['727', '2/15/1999', 'T6T', '1', '62.9', 'Canada '],
#    ['758', '2/15/1999', 'T2A', '1', '83.9', 'Canada '],
#    ['1014', '2/15/1999', 'T5H', '1', '86.6', 'Canada '],
#    ['1014', '2/15/1999', 'T5J', '2', '173.1', 'Canada '],
#    ['1157', '2/15/1999', 'T6K', '1', '377.9', 'Canada '],
#    ['1167', '2/15/1999', 'V5T', '1', '309.7', 'Canada '],
#    ['1948', '2/15/1999', 'V6M', '1', '293.9', 'Canada '],
#    ['1961', '2/15/1999', 'T5Y', '1', '97.1', 'Canada '],
#    ['2254', '2/15/1999', 'T5K', '1', '57.7', 'Canada '],
#    ['647', '6/1/2002', 'V5N', '1', '900.6', 'Canada '],
#    ['426', '6/1/2002', 'T2J', '1', '843.1', 'Canada '],
#    ['573', '6/1/2002', 'T6E', '1', '299', 'Canada '],
#    ['635', '6/1/2002', 'T2J', '1', '860.7', 'Canada '],
#    ['962', '3/15/1999', 'T5B', '1', '509.2', 'Canada '],
#    ['979', '3/15/1999', 'T5Y', '1', '393.7', 'Canada '],
#    ['989', '3/15/1999', 'T2X', '1', '451.4', 'Canada '],
#    ['992', '3/15/1999', 'V6Z', '1', '288.7', 'Canada '],
#    ['1008', '3/15/1999', 'V5V', '1', '236.2', 'Canada '],
#    ['1157', '3/15/1999', 'T2J', '1', '377.9', 'Canada '],
#    ['1191', '3/15/1999', 'V5V', '1', '262.4', 'Canada '],
#    ['1191', '3/15/1999', 'R2G', '1', '262.4', 'Canada '],
#    ['1227', '3/15/1999', 'T1Y', '1', '314.9', 'Canada '],
#    ['1330', '3/15/1999', 'V5N', '1', '92.8', 'Canada '],
#    ['2057', '3/15/1999', 'T6V', '1', '472.4', 'Canada '],
#    ['2204', '3/15/1999', 'V7Y', '1', '173.2', 'Canada '],
#    ['2211', '3/15/1999', 'V5Z', '1', '104.9', 'Canada '],
#    ['433', '3/15/1999', 'T5K', '1', '804.3', 'Canada '],
#    ['606', '3/15/1999', 'T2C', '1', '314.7', 'Canada '],
#    ['606', '3/15/1999', 'T6J', '1', '314.7', 'Canada '],
#    ['609', '3/15/1999', 'T5Y', '1', '778.8', 'Canada '],
#    ['645', '3/15/1999', 'V6H', '1', '746.5', 'Canada '],
#    ['676', '3/15/1999', 'T6V', '1', '801.9', 'Canada '],
#    ['726', '3/15/1999', 'T6G', '1', '115.4', 'Canada '],
#    ['726', '3/15/1999', 'V5Z', '1', '115.4', 'Canada '],
#    ['758', '3/15/1999', 'T2X', '1', '83.9', 'Canada '],
#    ['2359', '6/7/2002', 'V7W', '1', '430.4', 'Canada '],
#    ['964', '6/7/2002', 'T5K', '1', '335.9', 'Canada '],
#    ['979', '6/7/2002', 'V6C', '1', '393.7', 'Canada '],
#    ['1182', '6/7/2002', 'T6S', '1', '157.4', 'Canada '],
#    ['992', '6/7/2002', 'V7K', '1', '278.2', 'Canada '],
#    ['1000', '6/7/2002', 'V6N', '1', '89.2', 'Canada '],
#    ['1003', '6/7/2002', 'T3C', '1', '86.6', 'Canada '],
#    ['753', '6/8/2002', 'T2J', '1', '246.7', 'Canada '],
#    ['754', '6/8/2002', 'T2J', '1', '246.7', 'Canada '],
#    ['1062', '6/10/2002', 'T6R', '1', '149.6', 'Canada '],
#    ['2241', '6/10/2002', 'V6Z', '1', '89.2', 'Canada '],
#    ['2359', '6/10/2002', 'V5Z', '1', '430.4', 'Canada '],
#    ['964', '6/10/2002', 'V6T', '1', '320.2', 'Canada '],
#    ['1061', '6/10/2002', 'T6R', '1', '149.6', 'Canada '],
#    ['2240', '6/10/2002', 'V6Z', '1', '89.2', 'Canada '],
#    ['767', '3/15/1999', 'V7T', '1', '104.9', 'Canada '],
#    ['768', '3/15/1999', 'T6T', '1', '104.9', 'Canada '],
#    ['921', '3/15/1999', 'T3C', '1', '524.9', 'Canada '],
#    ['992', '3/15/1999', 'T6J', '1', '288.7', 'Canada '],
#    ['1046', '3/15/1999', 'T6H', '1', '99.7', 'Canada '],
#    ['1053', '3/15/1999', 'T6J', '1', '251.9', 'Canada '],
#    ['1082', '3/15/1999', 'T3G', '1', '225.7', 'Canada '],
#    ['1191', '3/15/1999', 'T1Y', '1', '262.4', 'Canada '],
#    ['1329', '3/15/1999', 'V5N', '1', '92.8', 'Canada '],
#    ['964', '6/12/2002', 'V6Z', '1', '335.9', 'Canada '],
#    ['670', '6/12/2002', 'T5K', '1', '871.2', 'Canada '],
#    ['573', '6/12/2002', 'V6R', '1', '299', 'Canada '],
#    ['753', '6/12/2002', 'V6M', '1', '246.7', 'Canada '],
#    ['596', '6/13/2002', 'T6T', '1', '776.7', 'Canada '],
#    ['992', '6/13/2002', 'V7P', '1', '278.2', 'Canada '],
#    ['467', '6/13/2002', 'V6J', '1', '900.6', 'Canada '],
#    ['691', '6/13/2002', 'T6S', '1', '351.5', 'Canada '],
#    ['990', '6/13/2002', 'V6T', '1', '440.9', 'Canada '],
#    ['992', '6/13/2002', 'T2J', '1', '278.2', 'Canada '],
#    ['1034', '6/13/2002', 'T5V', '1', '892.2', 'Canada '],
#    ['1111', '6/13/2002', 'T2J', '1', '120.7', 'Canada '],
#    ['1215', '6/13/2002', 'V6Z', '1', '356.9', 'Canada '],
#    ['910', '6/13/2002', 'V5K', '1', '430.4', 'Canada '],
#    ['725', '3/15/1999', 'T6G', '1', '115.4', 'Canada '],
#    ['725', '3/15/1999', 'V5Z', '1', '115.4', 'Canada '],
#    ['797', '3/15/1999', 'T5W', '1', '301.8', 'Canada '],
#    ['797', '3/15/1999', 'V7X', '1', '301.8', 'Canada '],
#    ['833', '3/15/1999', 'V6T', '1', '782.2', 'Canada '],
#    ['837', '3/15/1999', 'T2C', '1', '839.9', 'Canada '],
#    ['901', '3/15/1999', 'T2S', '1', '409.4', 'Canada '],
#    ['910', '3/15/1999', 'T2X', '2', '829.4', 'Canada '],
#    ['921', '3/15/1999', 'V6B', '1', '524.9', 'Canada '],
#    ['990', '3/15/1999', 'V6M', '1', '456.7', 'Canada '],
#    ['1166', '3/15/1999', 'V6R', '1', '535.4', 'Canada '],
#    ['1188', '3/15/1999', 'T2N', '1', '472.4', 'Canada '],
#    ['1948', '3/15/1999', 'V6T', '1', '296.6', 'Canada '],
#    ['2045', '3/15/1999', 'T2C', '1', '409.4', 'Canada '],
#    ['2070', '3/15/1999', 'T6T', '1', '519.7', 'Canada '],
#    ['2074', '3/15/1999', 'V5N', '1', '328.1', 'Canada '],
#    ['2083', '3/15/1999', 'T6E', '1', '309.7', 'Canada '],
#    ['2235', '3/15/1999', 'V7R', '1', '65.6', 'Canada '],
#    ['2254', '3/15/1999', 'V5N', '1', '57.7', 'Canada '],
#    ['2282', '3/15/1999', 'T6T', '1', '304.4', 'Canada '],
#    ['2380', '3/15/1999', 'T6G', '1', '309.7', 'Canada '],
#    ['2407', '3/15/1999', 'T6T', '1', '73.4', 'Canada '],
#    ['2407', '3/15/1999', 'V5T', '2', '146.9', 'Canada '],
#    ['93', '4/15/1999', 'V6T', '1', '992.2', 'Canada '],
#    ['396', '4/15/1999', 'T6W', '1', '857.1', 'Canada '],
#    ['580', '4/15/1999', 'V6H', '1', '734.7', 'Canada '],
#    ['609', '4/15/1999', 'T3C', '1', '778.8', 'Canada '],
#    ['2282', '3/15/1999', 'L5R', '1', '304.4', 'Canada '],
#    ['726', '6/10/2002', 'M6P', '1', '120.7', 'Canada '],
#    ['2352', '6/10/2002', 'R3V', '1', '367.4', 'Canada '],
#    ['2379', '6/10/2002', 'M4P', '1', '178.4', 'Canada '],
#    ['1174', '6/11/2002', 'R3Y', '1', '577.4', 'Canada '],
#    ['2054', '6/11/2002', 'L5P', '1', '545.9', 'Canada '],
#    ['964', '6/11/2002', 'L5N', '1', '330.7', 'Canada '],
#    ['2053', '6/11/2002', 'L5N', '1', '325.4', 'Canada '],
#    ['433', '6/11/2002', 'L5N', '1', '851.5', 'Canada '],
#    ['1114', '6/11/2002', 'L5N', '1', '167.9', 'Canada '],
#    ['396', '6/11/2002', 'H1B', '1', '892.2', 'Canada '],
#    ['910', '4/15/1999', 'K1K', '1', '414.7', 'Canada '],
#    ['922', '4/15/1999', 'R3G', '1', '472.4', 'Canada '],
#    ['1082', '4/15/1999', 'L4X', '1', '225.7', 'Canada '],
#    ['1112', '4/15/1999', 'R3B', '1', '116.5', 'Canada '],
#    ['1157', '4/15/1999', 'K1K', '1', '377.9', 'Canada '],
#    ['964', '6/13/2002', 'M4E', '1', '330.7', 'Canada '],
#    ['964', '6/13/2002', 'M5A', '1', '335.9', 'Canada '],
#    ['910', '6/13/2002', 'R3G', '1', '430.4', 'Canada '],
#    ['967', '6/13/2002', 'K1N', '1', '656.2', 'Canada '],
#    ['1215', '6/14/2002', 'M6R', '1', '356.9', 'Canada '],
#    ['1186', '6/14/2002', 'L5N', '1', '425.2', 'Canada '],
#    ...])]

# %% [markdown]
# #### sortByKey
# Permite ordenar los datos a partir de una clave

# %%
rdd = sc.textFile("Datos/pdi_sales.csv")
paisesUnidades = rdd.map(lambda x: (x.split(";")[-1].strip(), x.split(";")[3]))
header = paisesUnidades.first()
paisesUnidadesSinHeader = paisesUnidades.filter(lambda linea: linea != header)
paisesTotalUnidades = paisesUnidadesSinHeader.reduceByKey(lambda a, b: float(a) + float(b))
print(paisesTotalUnidades.collect())
unidadesPaises = paisesTotalUnidades.map(lambda x: (int(x[1]), x[0]))
unidadesPaises.collect()
# Out:
# [('Mexico', 223463.0), ('France', 327730.0), ('Germany', 244265.0), ('Canada', 77609.0)]
# [(223463, 'Mexico'),
#  (327730, 'France'),
#  (244265, 'Germany'),
#  (77609, 'Canada')]

# %% [markdown]
# Y a continuación los ordenamos:

# %%
unidadesPaisesOrdenadas = unidadesPaises.sortByKey()
unidadesPaisesOrdenadas.collect()
# Out:
# [(11003916, 'France'),
#  (34114930, 'Canada'),
#  (103645802, 'Mexico'),
#  (131930510, 'Germany')]

# %% [markdown]
# Veamos otro ejemplo, pero en este caso la ordenación va a ser de forma descendente:

# %%
pairs = [("a", 5), ("d", 7), ("c", 2), ("b", 3)]
raw_rdd = sc.parallelize(pairs)
sortkey_rdd = raw_rdd.sortByKey(ascending=False)
sortkey_rdd.collect()
# Out:
# [('d', 7), ('c', 2), ('b', 3), ('a', 5)]

# %% [markdown]
# #### sortBy
# Ordena los datos según la función especificada.

# %%
unidadesPaises.sortBy(lambda x: x[1]).collect()
# Out:
# [(34114930, 'Canada'),
#  (11003916, 'France'),
#  (131930510, 'Germany'),
#  (103645802, 'Mexico')]

# %% [markdown]
# Veamos otro ejemplo:

# %%
pairs = [ ("a", 5, 10), ("d", 7, 12), ("c", 2, 11), ("b", 3, 9)]
raw_rdd = sc.parallelize(pairs)
sort_out = raw_rdd.sortBy(lambda x : x[2])
result = sort_out.collect()
print(*result, sep='\n')
# Out:
# ('b', 3, 9)
# ('a', 5, 10)
# ('c', 2, 11)
# ('d', 7, 12)

# %% [markdown]
# ## PARTICIONES
# Spark organiza los datos en particiones, considerándolas divisiones lógicas de los datos entre los nodos del clúster.
#
# Cada una de las particiones va a llevar asociada una tarea de ejecución, de manera que a más particiones, mayor paralelización del proceso.
#
# Veamos con código como podemos trabajar con las particiones:

# %%
rdd = sc.parallelize([1, 1, 2, 2, 3, 3, 4, 5])
rdd.getNumPartitions()
# Out:
# 16

# %%
rdd = sc.parallelize([1, 1, 2, 2, 3, 3, 4, 5], 2)
rdd.getNumPartitions()
# Out:
# 2

# %%
rddE = sc.textFile("Datos/empleados.txt")
rddE.getNumPartitions()
# Out:
# 2

# %%
rddE = sc.textFile("Datos/empleados.txt", 3)
rddE.getNumPartitions()
# Out:
# 3

# %% [markdown]
# La mayoría de las operaciones que trabajan con los datos admiten un parámetro extra indicando la cantidad de particiones con las que queremos trabajar.

# %% [markdown]
# ### mapPartitions
# A diferencia de la transformación map que se invoca por cada elemento, mapPartitions se llama por cada partición.
#
# La función que recibe como parámetro recogerá como entrada un iterador con los elementos de cada partición:

# %%
rdd = sc.parallelize([1, 1, 2, 2, 3, 3, 4, 5], 2)

# %%
rddParticiones = rdd.mapPartitions(lambda x: [list(x)])
rddParticiones.collect()
# Out:
# [[1, 1, 2, 2], [3, 3, 4, 5]]

# %%
resultadoRdd = rdd.mapPartitions(lambda x: [sum(x)])
resultadoRdd.collect()
# Out:
# [6, 15]

# %% [markdown]
# En el ejemplo, ha dividido los datos en dos particiones, la primera con [1, 1, 2, 2] y la otra con [3, 3, 4, 5], y de ahí el resultado de sumar sus elementos es [6, 15].

# %% [markdown]
# ### mapPartitionsWithIndex
# De forma similar al caso anterior, pero ahora recibe una función cuyos parámetros son el índice de la partición y el iterador con los datos de la misma.

# %%
def mpwi(indice, iterador):
    return [(indice, list(iterador))]

resultadoRdd = rdd.mapPartitionsWithIndex(mpwi)
resultadoRdd.collect()
# Out:
# [(0, [1, 1, 2, 2]), (1, [3, 3, 4, 5])]

# %% [markdown]
# ### coalesce
# Obtenemos un nuevo RDD con el nuevo número de particiones que queremos (más pequeño, coalesce es para reducir)

# %%
rdd = sc.parallelize([1, 1, 2, 2, 3, 3, 4, 5], 3)
rdd.getNumPartitions()
# Out:
# 3

# %%
rdd1p = rdd.coalesce(1)
rdd1p.getNumPartitions()
# Out:
# 1

# %% [markdown]
# ### repartition
# Obtenemos un nuevo RDD con la cantidad exacta de particiones deseadas (al reducir las particiones, repartition realiza un shuffle para redistribuir los datos, por lo tanto, si queremos reducir la cantidad de particiones, es más eficiente utilizar coalesce):

# %%
rdd = sc.parallelize([1, 1, 2, 2, 3, 3, 4, 5], 3)
rdd.getNumPartitions()
# Out:
# 3

# %%
rdd2p = rdd.repartition(4)
rdd2p.getNumPartitions()
# Out:
# 4
